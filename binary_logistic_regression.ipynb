# %% [markdown]
# # Binary Logistic Regression / Classification
#
# ## Background
# Binary classification is one of the most fundamental and common tasks in machine learning and deep learning.
# At its core, it's a supervised learning problem where the goal is to categorize input data into one of two possible classes or categories.
# Think of it as teaching a machine to make a "yes" or "no" decision.
# Examples of binary classification's applications are:
#
# - Spam Detection: Classifying an email as either 'spam' or 'not spam'.
# - Medical Diagnosis: Determining if a patient has a certain disease.
# - Credit Scoring: Deciding whether a loan applicant is a 'good credit risk' or a 'bad credit risk'.
#
# A sigmoid activated multi-input, single-output linear model is a decent candidate for this job.
# In this practice, you'll train such a model to categorize samples from a toy dataset into two classes.
#
# ## Objectives
# - Train a simple neural network model.
#     - Apply sigmoid activation on a linear model.
#     - Implement binary cross entropy evaluation.
#     - Practice vectorized computing.
# - Assess model's performance using a variety of metrics.
#
#
# ## Exercises:
#
# 1. <font color=#582C83>(5%) Data Pre-Processing</font>
# 2. <font color=#582C83>(10%) Model Creation</font>
# 3. <font color=#582C83>(20%) Model Assessment</font>
# 4. <font color=#582C83>(10%) Gradient of BCE Loss</font>
# 5. <font color=#582C83>(30%) Gradient Descent Model Optimization</font>
# 6. <font color=#582C83>(25%) Classification Metrics</font>

# %% [markdown]
# ## 1. Load and Pre-Process Training Dataset
#
# The dataset,
# $$\mathcal{D} = \{\mathbf{X}, \mathbf{y}\} = \begin{bmatrix} ^{(1)} \mathbf{x} & ^{(1)} y \\ ^{(2)} \mathbf{x} & ^{(2)} y \\ \vdots \\ ^{(M)} \mathbf{x} & ^{(M)} y \end{bmatrix}$$
# consists $M$ samples.
#
# Each sample has $N$ features: $^{(i)} \mathbf{x} = [^{(i)} x_1, ^{(i)} x_2, \dots, ^{(i)} x_N]$ and is labeled as $^{(i)} y \in \{0, 1\}$, where $i \in \{1, 2, ..., M\}$.
#
# In this practice, we make a toy dataset using [scikit-learn](https://scikit-learn.org/stable/index.html)'s [datasets](https://scikit-learn.org/stable/api/sklearn.datasets.html) module.
# The dataset has $M=2048$ samples, and $N=2$ features.

# %%
from sklearn.datasets import make_blobs
import numpy as np
import matplotlib.pyplot as plt

features_raw, labels_raw = make_blobs(n_samples=2048, centers=np.array([[5, 5], [7, 8]]), cluster_std=1.0, random_state=3321)
# Visualize the raw data
plt.scatter(
    features_raw[:, 0], # feature 1 values (x coords)
    features_raw[:, 1], # feature 2 values (y coords)
    s=5*np.ones(labels_raw.size), # marker size all set to 1
    c=labels_raw, # colorized labels: 0:blue, 1:red
    cmap='coolwarm'  # color map
)

# %% [markdown]
# ### <font color=#582C83>(5%) Exercise 1: Data Pre-Processing</font>
# 1. In machine learning, it is prefered to scale features into the same range: $[0, 1]$.
# 2. To avoid dimension mismatch, reshape features and labels array into two dimensions is recommended.

# %%
### START CODING HERE ### (≈ 2 lines of code)
features_train = features_raw / features_raw.max(axis = 0) # Scale features to [0, 1]
labels_train = labels_raw.reshape(-1, 1) # Reshape labels to be a column vector
### END CODING HERE ### 

# Sanity check
print(f"Samples of pre-processed features:\n {features_train[-4:]}")
print(f"Samples of pre-processed labels:\n {labels_train[-4:]}")  # Print last 4 samples of features and labels
print(f"Shape of pre-processed features:\n {features_train.shape}.")
print(f"Shape of pre-processed labels:\n {labels_train.shape}")  # Print shapes of features and labels   

# Visualize
plt.scatter(
    features_train[:, 0], 
    features_train[:, 1], 
    s=5*np.ones(labels_train.size), 
    c=labels_train, 
    cmap='coolwarm'  # color map
)
# Out:
# Samples of pre-processed features:
#  [[0.60810041 0.36828791]
#  [0.85139165 0.63786153]
#  [0.57346525 0.38949334]
#  [0.77146837 0.71406137]]
# Samples of pre-processed labels:
#  [[0]
#  [1]
#  [0]
#  [1]]
# Shape of pre-processed features:
#  (2048, 2).
# Shape of pre-processed labels:
#  (2048, 1)

# %% [markdown]
# **Expected Outcomes**:
# ```console
# Samples of pre-processed features:
#  [[0.60810041 0.36828791]
#  [0.85139165 0.63786153]
#  [0.57346525 0.38949334]
#  [0.77146837 0.71406137]]
# Samples of pre-processed labels:
#  [[0]
#  [1]
#  [0]
#  [1]]
# Shape of pre-processed features:
#  (2048, 2).
# Shape of pre-processed labels:
#  (2048, 1)
# ```

# %% [markdown]
# ## 2. Create a Non-linear Multi-Input Single-Output Model
# Let's create a nonlinear model by applying a sigmoid function to the output of a linear model.
#
# $$\mathbf{\hat{y}} = \sigma (\mathbf{X} \cdot \mathbf{w}^T + \mathbf{b}) = \sigma(\mathbf{Z})$$
#
# The sigmoid function can be represented as,
#
# $$\sigma(\mathbf{Z}) = \frac{1}{1 + e^{-\mathbf{Z}}}$$
#
# The linear part of the model is governed by a parameter vector
# $$\mathbf{w} = [w_1, w_2, ..., w_N]_{(1, N)}$$
#
# and a bias vector
# $$\mathbf{b} = \begin{bmatrix} b \\ b \\ \vdots \\ b \end{bmatrix}_{(M, 1)}$$
#
# And, in this practice $M=2048$ and $N=2$
#
# ### <font color=#582C83>(10%) Exercise 2: Model Creation</font>
# Let's translate math to code.

# %%
def forward(in_features, weights, bias):
    """
    Compute the linear combination of inputs and weights plus bias.
    
    Args:
        in_features (np.ndarray): Input features of shape (M, N).
        weights (np.ndarray): Weights of shape (1, N).
        bias (float): Bias term.  
    Returns:
        predictions: Linear combination result of shape (M, 1).
    """
    ### START CODING HERE ### (≈ 2 lines of code)
    def sigmoid(z):
        return 1 / (1 + np.exp(-z))
    predictions = sigmoid(np.dot(in_features, weights.T) + bias)
    return predictions
    ### END CODING HERE ###

# Sanity check
w_dummy = np.array([[1.2, -2.3]])
b_dummy = 1.0
print(f"Samples of dummy prediction:\n {forward(features_train, w_dummy, b_dummy)[-4:]}")  # Print last 4 samples of dummy prediction

# Visualize dummy model decision boundary
plt.scatter(features_train[:, 0], features_train[:, 1], s=5*np.ones(labels_train.size), c=labels_train, cmap='coolwarm')
# Create a meshgrid of points over the feature space
xx, yy = np.meshgrid(np.linspace(0., 1., 300),
                     np.linspace(0., 1., 300))
zz = w_dummy[0, 0] * xx + w_dummy[0, 1] * yy + b_dummy - 0.5
plt.contourf(xx, yy, zz, levels=[-np.inf, 0, np.inf], colors=['blue', 'red'], alpha=0.25)
# Out:
# Samples of dummy prediction:
#  [[0.70737278]
#  [0.63519949]
#  [0.68833004]
#  [0.5703847 ]]

# %% [markdown]
# **Expected Outcomes**:
# >
# ```console
# Samples of dummy prediction:
#  [[0.70737278]
#  [0.63519949]
#  [0.68833004]
#  [0.5703847 ]]
# ```

# %% [markdown]
# ## 3. Evaluate Model
# As same as the linear regression, we need to evaluate model performance.
# It is OK to use a Mean Squared Error (MSE) function to compute the model loss.
# It is **recommended** to use a Binary Cross Entropy (BCE) function to assess the model for a binary classification problem.
# Binary Cross Entropy (BCE) is a differentiable metric.
# $$\mathcal{L}(\mathbf{\hat{y}}, \mathbf{y}) = \frac{1}{M} \Sigma [-\mathbf{y} \log \hat{\mathbf{y}} - (1 - \mathbf{y}) \log(1 - \hat{\mathbf{y}})]$$
#
# There are other useful metrics, such as accuracy. But they are not differentiable.
# Let $TP$ be number of true positive predictions, $TN$ be number of true negative predictions, $FP$ be number of false positive predictions, $FN$ be number of false negative predictions.
# The accuracy can be calculated by:
# $$Accuracy = \frac{TP + TN}{TP+FP+TN+FN}$$
#
# ### <font color=#582C83>(20%) Exercise 3: Model Assessment</font>
# 1. Evaluate model loss with BCE.
# 2. Assess model predictions accuracy.

# %%
def bce_loss(predictions, labels):
    """
    Compute the Binary Cross Entropy (BCE) loss.
    
    Args:
        predictions (np.ndarray): Predicted probabilities of shape (M, 1).
        labels (np.ndarray): True binary labels of shape (M, 1).
    Returns:
        loss: BCE loss value (float).
    """
    ### START CODING HERE ### (≈ 1 line)
    loss = - np.mean(labels * np.log(predictions + 1e-15) + (1 - labels) * np.log(1 - predictions + 1e-15))  # BCE loss formula with numerical stability
    return loss
    ### END CODING HERE ###

def accuracy(predictions, labels):
    """
    Compute the accuracy of predictions.
    
    Args:
        predictions (np.ndarray): Predicted probabilities of shape (M, 1).
        labels (np.ndarray): True binary labels of shape (M, 1).
    Returns:
        acc: Accuracy value (float).
    """
    ### START CODING HERE ### (≈ 2 lines)
    predicted_classes = predictions >= 0.5  # Convert probabilities to binary classes
    acc = np.mean(predicted_classes == labels)  # Calculate accuracy
    return acc
    ### END CODING HERE ###

# Sanity check
preds_dummy = forward(features_train, w_dummy, b_dummy)
print(f"Dummy model BCE loss: {bce_loss(preds_dummy, labels_train)}")
print(f"Dummy model accuracy: {accuracy(preds_dummy, labels_train) * 100}%")
# Out:
# Dummy model BCE loss: 0.8189666983092307
# Dummy model accuracy: 42.67578125%

# %% [markdown]
# **Expected Output**:
# >
# ```console
# Dummy model BCE loss: 0.8189666983092332
# Dummy model accuracy: 42.67578125%
# ```

# %% [markdown]
# ## 4. Compute Gradient of Loss
# Compute gradient of the BCE loss:
#
# $$\frac{\partial \mathcal{L}}{\partial \mathbf{w}} = \begin{bmatrix} \frac{\partial \mathcal{L}}{\partial w_1} & \frac{\partial \mathcal{L}}{\partial w_2} & \dots & \frac{\partial \mathcal{L}}{\partial w_N} \end{bmatrix} = \frac{1}{M} (\hat{\mathbf{y}} - \mathbf{y})^T \cdot \mathbf{X}$$
# $$\frac{\partial \mathcal{L}}{\partial b}  = \overline{\hat{\mathbf{y}} - \mathbf{y}} $$
#
# ### <font color=#582C83>(10%) Exercise 4: Gradient of BCE Loss</font>

# %%
def gradient(predictions, labels, in_features):
    """
    Compute the gradient of the BCE loss with respect to weights and bias.
    
    Args:
        predictions (np.ndarray): Predicted probabilities of shape (M, 1).
        labels (np.ndarray): True binary labels of shape (M, 1).
        in_features (np.ndarray): Input features of shape (M, N).
    Returns:
        dw: Gradient with respect to weights of shape (1, N).
        db: Gradient with respect to bias (float).
    """
    ### START CODING HERE ### (≈ 3 lines of code)
    M = labels.shape[0]  # Number of samples
    dw = np.dot((predictions - labels).T, in_features) / M  # Gradient w.r.t. weights
    db = np.sum(predictions - labels) / M  # Gradient w.r.t. bias
    return dw, db
    ### END CODING HERE ###

# Sanity check
dw_dummy, db_dummy = gradient(preds_dummy, labels_train, features_train)
print(f"Dummy model gradient w.r.t. weights: {dw_dummy}, shape: {dw_dummy.shape}")
print(f"Dummy model gradient w.r.t. bias: {db_dummy}")
# Out:
# Dummy model gradient w.r.t. weights: [[ 0.01011904 -0.01882587]], shape: (1, 2)
# Dummy model gradient w.r.t. bias: 0.10192657501589689

# %% [markdown]
# **Expected Output**:
# >
# ```console
# Dummy model gradient w.r.t. weights: [[ 0.01011904 -0.01882587]], shape: (1, 2)
# Dummy model gradient w.r.t. bias: 0.10192657501589689
# ```

# %% [markdown]
# ## 5. Update Model Parameters
#
#
# By tweaking the model parameters along the gradient a small step (learning rate, $\alpha$) iteratively, we expect to bring the BCE loss down to a reasonable scale.
#
# - $\text{Initialize } \mathbf{w} \text{ and } b$
# - $\text{Repeat until converge}$
#     - $\mathbf{w} = \mathbf{w} - \alpha \frac{\partial \mathcal{L}}{\partial \mathbf{w}}$
#     - $b = b - \alpha \frac{\partial \mathcal{L}}{\partial b}$
#
#
#
# ### <font color=#582C83>(30%) Exercise 5: Gradient Descent Model Optimization</font>
# 1. Initialize weights and bias
# 2. Set learning rate and number of iterations
# 3. Repeat following steps:
#
#     1. Make predictions
#     2. Assess model
#     3. Compute gradient of loss
#     4. Update weights and bias
#
# <font color=red>**Note: bring training accuracy over 95% within 10000 iterations**</font>

# %%
# START CODING HERE ### (≈ 10 lines of code)
# Initialize parameters
w = w_dummy.copy()  # Initialize weights
b = 0.0  # Initialize bias

# Set hyperparameters
learning_rate = 0.1
num_iters = 10000

# Reserve loss and accuracy storage
losses_train = []
accuracies_train = []

# Training loop
for i in range(num_iters):
    preds_train = forward(features_train, w, b)  # Forward pass
    loss_train = bce_loss(preds_train, labels_train)  # Assess model loss
    acc_train = accuracy(preds_train, labels_train)  # Assess model accuracy
    print(f"Iteration {i+1}/{num_iters}, Loss: {loss_train:.4f}, Accuracy: {acc_train*100:.2f}%")
    losses_train.append(loss_train)
    accuracies_train.append(acc_train)
    dw, db = gradient(preds_train, labels_train, features_train)  # Compute gradients
    w = w - learning_rate * dw  # Update weights
    b = b - learning_rate * db  # Update bias

### END CODING HERE ###

# Plot training loss and accuracy
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(losses_train, label='Training Loss')
plt.xlabel('Iteration')
plt.ylabel('BCE Loss')
plt.title('Training Loss over Iterations')
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(np.array(accuracies_train) * 100, label='Training Accuracy', color='orange')
plt.xlabel('Iteration')
plt.ylabel('Accuracy (%)')
plt.title('Training Accuracy over Iterations')
plt.legend()
# Out:
# Iteration 1/10000, Loss: 0.8375, Accuracy: 47.36%
# Iteration 2/10000, Loss: 0.8315, Accuracy: 46.73%
# Iteration 3/10000, Loss: 0.8260, Accuracy: 46.14%
# Iteration 4/10000, Loss: 0.8208, Accuracy: 45.70%
# Iteration 5/10000, Loss: 0.8160, Accuracy: 45.41%
# Iteration 6/10000, Loss: 0.8115, Accuracy: 44.38%
# Iteration 7/10000, Loss: 0.8073, Accuracy: 43.51%
# Iteration 8/10000, Loss: 0.8034, Accuracy: 42.43%
# Iteration 9/10000, Loss: 0.7998, Accuracy: 41.31%
# Iteration 10/10000, Loss: 0.7964, Accuracy: 39.75%
# Iteration 11/10000, Loss: 0.7933, Accuracy: 38.87%
# Iteration 12/10000, Loss: 0.7903, Accuracy: 37.70%
# Iteration 13/10000, Loss: 0.7876, Accuracy: 36.52%
# Iteration 14/10000, Loss: 0.7850, Accuracy: 35.30%
# Iteration 15/10000, Loss: 0.7826, Accuracy: 34.42%
# Iteration 16/10000, Loss: 0.7804, Accuracy: 33.79%
# Iteration 17/10000, Loss: 0.7783, Accuracy: 33.45%
# Iteration 18/10000, Loss: 0.7763, Accuracy: 33.30%
# Iteration 19/10000, Loss: 0.7745, Accuracy: 33.30%
# Iteration 20/10000, Loss: 0.7728, Accuracy: 32.67%
# Iteration 21/10000, Loss: 0.7711, Accuracy: 32.23%
# Iteration 22/10000, Loss: 0.7696, Accuracy: 31.98%
# Iteration 23/10000, Loss: 0.7681, Accuracy: 31.69%
# Iteration 24/10000, Loss: 0.7668, Accuracy: 31.93%
# Iteration 25/10000, Loss: 0.7655, Accuracy: 31.49%
# Iteration 26/10000, Loss: 0.7642, Accuracy: 31.35%
# Iteration 27/10000, Loss: 0.7630, Accuracy: 31.45%
# Iteration 28/10000, Loss: 0.7619, Accuracy: 31.49%
# Iteration 29/10000, Loss: 0.7609, Accuracy: 31.40%
# Iteration 30/10000, Loss: 0.7599, Accuracy: 31.10%
# Iteration 31/10000, Loss: 0.7589, Accuracy: 31.15%
# Iteration 32/10000, Loss: 0.7580, Accuracy: 31.25%
# Iteration 33/10000, Loss: 0.7571, Accuracy: 31.74%
# Iteration 34/10000, Loss: 0.7562, Accuracy: 31.88%
# Iteration 35/10000, Loss: 0.7554, Accuracy: 31.98%
# Iteration 36/10000, Loss: 0.7546, Accuracy: 32.13%
# Iteration 37/10000, Loss: 0.7538, Accuracy: 32.18%
# Iteration 38/10000, Loss: 0.7531, Accuracy: 32.47%
# Iteration 39/10000, Loss: 0.7524, Accuracy: 32.52%
# Iteration 40/10000, Loss: 0.7517, Accuracy: 32.52%
# Iteration 41/10000, Loss: 0.7510, Accuracy: 32.86%
# Iteration 42/10000, Loss: 0.7503, Accuracy: 33.40%
# Iteration 43/10000, Loss: 0.7497, Accuracy: 33.40%
# Iteration 44/10000, Loss: 0.7491, Accuracy: 33.25%
# Iteration 45/10000, Loss: 0.7484, Accuracy: 33.69%
# Iteration 46/10000, Loss: 0.7478, Accuracy: 33.84%
# Iteration 47/10000, Loss: 0.7472, Accuracy: 34.13%
# Iteration 48/10000, Loss: 0.7467, Accuracy: 34.42%
# Iteration 49/10000, Loss: 0.7461, Accuracy: 34.47%
# Iteration 50/10000, Loss: 0.7455, Accuracy: 34.91%
# Iteration 51/10000, Loss: 0.7450, Accuracy: 34.96%
# Iteration 52/10000, Loss: 0.7444, Accuracy: 35.45%
# Iteration 53/10000, Loss: 0.7439, Accuracy: 35.74%
# Iteration 54/10000, Loss: 0.7433, Accuracy: 36.04%
# Iteration 55/10000, Loss: 0.7428, Accuracy: 36.33%
# Iteration 56/10000, Loss: 0.7423, Accuracy: 36.82%
# Iteration 57/10000, Loss: 0.7418, Accuracy: 37.01%
# Iteration 58/10000, Loss: 0.7413, Accuracy: 37.30%
# Iteration 59/10000, Loss: 0.7408, Accuracy: 37.70%
# Iteration 60/10000, Loss: 0.7403, Accuracy: 37.94%
# Iteration 61/10000, Loss: 0.7398, Accuracy: 38.13%
# Iteration 62/10000, Loss: 0.7393, Accuracy: 38.33%
# Iteration 63/10000, Loss: 0.7388, Accuracy: 38.87%
# Iteration 64/10000, Loss: 0.7383, Accuracy: 39.01%
# Iteration 65/10000, Loss: 0.7378, Accuracy: 39.26%
# Iteration 66/10000, Loss: 0.7373, Accuracy: 39.36%
# Iteration 67/10000, Loss: 0.7368, Accuracy: 39.45%
# Iteration 68/10000, Loss: 0.7364, Accuracy: 39.50%
# Iteration 69/10000, Loss: 0.7359, Accuracy: 39.75%
# Iteration 70/10000, Loss: 0.7354, Accuracy: 40.19%
# Iteration 71/10000, Loss: 0.7349, Accuracy: 40.33%
# Iteration 72/10000, Loss: 0.7345, Accuracy: 40.43%
# Iteration 73/10000, Loss: 0.7340, Accuracy: 40.62%
# Iteration 74/10000, Loss: 0.7335, Accuracy: 40.77%
# Iteration 75/10000, Loss: 0.7331, Accuracy: 40.97%
# Iteration 76/10000, Loss: 0.7326, Accuracy: 41.21%
# Iteration 77/10000, Loss: 0.7321, Accuracy: 41.50%
# Iteration 78/10000, Loss: 0.7317, Accuracy: 41.80%
# Iteration 79/10000, Loss: 0.7312, Accuracy: 42.09%
# Iteration 80/10000, Loss: 0.7308, Accuracy: 42.29%
# Iteration 81/10000, Loss: 0.7303, Accuracy: 42.48%
# Iteration 82/10000, Loss: 0.7298, Accuracy: 42.72%
# Iteration 83/10000, Loss: 0.7294, Accuracy: 43.12%
# Iteration 84/10000, Loss: 0.7289, Accuracy: 43.21%
# Iteration 85/10000, Loss: 0.7285, Accuracy: 43.46%
# Iteration 86/10000, Loss: 0.7280, Accuracy: 43.65%
# Iteration 87/10000, Loss: 0.7276, Accuracy: 43.70%
# Iteration 88/10000, Loss: 0.7271, Accuracy: 43.85%
# Iteration 89/10000, Loss: 0.7267, Accuracy: 44.04%
# Iteration 90/10000, Loss: 0.7262, Accuracy: 44.14%
# Iteration 91/10000, Loss: 0.7258, Accuracy: 44.14%
# Iteration 92/10000, Loss: 0.7253, Accuracy: 44.24%
# Iteration 93/10000, Loss: 0.7249, Accuracy: 44.34%
# Iteration 94/10000, Loss: 0.7244, Accuracy: 44.29%
# Iteration 95/10000, Loss: 0.7240, Accuracy: 44.38%
# Iteration 96/10000, Loss: 0.7235, Accuracy: 44.48%
# Iteration 97/10000, Loss: 0.7231, Accuracy: 44.63%
# Iteration 98/10000, Loss: 0.7226, Accuracy: 44.73%
# Iteration 99/10000, Loss: 0.7222, Accuracy: 44.78%
# Iteration 100/10000, Loss: 0.7218, Accuracy: 45.02%
# Iteration 101/10000, Loss: 0.7213, Accuracy: 45.12%
# Iteration 102/10000, Loss: 0.7209, Accuracy: 45.21%
# Iteration 103/10000, Loss: 0.7204, Accuracy: 45.26%
# Iteration 104/10000, Loss: 0.7200, Accuracy: 45.36%
# Iteration 105/10000, Loss: 0.7196, Accuracy: 45.61%
# Iteration 106/10000, Loss: 0.7191, Accuracy: 45.65%
# Iteration 107/10000, Loss: 0.7187, Accuracy: 45.80%
# Iteration 108/10000, Loss: 0.7182, Accuracy: 45.95%
# Iteration 109/10000, Loss: 0.7178, Accuracy: 46.04%
# Iteration 110/10000, Loss: 0.7174, Accuracy: 46.09%
# Iteration 111/10000, Loss: 0.7169, Accuracy: 46.29%
# Iteration 112/10000, Loss: 0.7165, Accuracy: 46.39%
# Iteration 113/10000, Loss: 0.7160, Accuracy: 46.48%
# Iteration 114/10000, Loss: 0.7156, Accuracy: 46.63%
# Iteration 115/10000, Loss: 0.7152, Accuracy: 46.78%
# Iteration 116/10000, Loss: 0.7147, Accuracy: 47.07%
# Iteration 117/10000, Loss: 0.7143, Accuracy: 47.27%
# Iteration 118/10000, Loss: 0.7139, Accuracy: 47.36%
# Iteration 119/10000, Loss: 0.7134, Accuracy: 47.36%
# Iteration 120/10000, Loss: 0.7130, Accuracy: 47.61%
# Iteration 121/10000, Loss: 0.7126, Accuracy: 47.66%
# Iteration 122/10000, Loss: 0.7121, Accuracy: 47.80%
# Iteration 123/10000, Loss: 0.7117, Accuracy: 47.80%
# Iteration 124/10000, Loss: 0.7113, Accuracy: 48.05%
# Iteration 125/10000, Loss: 0.7108, Accuracy: 48.14%
# Iteration 126/10000, Loss: 0.7104, Accuracy: 48.19%
# Iteration 127/10000, Loss: 0.7100, Accuracy: 48.19%
# Iteration 128/10000, Loss: 0.7096, Accuracy: 48.44%
# Iteration 129/10000, Loss: 0.7091, Accuracy: 48.49%
# Iteration 130/10000, Loss: 0.7087, Accuracy: 48.63%
# Iteration 131/10000, Loss: 0.7083, Accuracy: 48.73%
# Iteration 132/10000, Loss: 0.7078, Accuracy: 48.93%
# Iteration 133/10000, Loss: 0.7074, Accuracy: 48.97%
# Iteration 134/10000, Loss: 0.7070, Accuracy: 49.17%
# Iteration 135/10000, Loss: 0.7066, Accuracy: 49.32%
# Iteration 136/10000, Loss: 0.7061, Accuracy: 49.41%
# Iteration 137/10000, Loss: 0.7057, Accuracy: 49.46%
# Iteration 138/10000, Loss: 0.7053, Accuracy: 49.56%
# Iteration 139/10000, Loss: 0.7049, Accuracy: 49.66%
# Iteration 140/10000, Loss: 0.7044, Accuracy: 49.66%
# Iteration 141/10000, Loss: 0.7040, Accuracy: 49.76%
# Iteration 142/10000, Loss: 0.7036, Accuracy: 49.76%
# Iteration 143/10000, Loss: 0.7032, Accuracy: 49.85%
# Iteration 144/10000, Loss: 0.7028, Accuracy: 49.95%
# Iteration 145/10000, Loss: 0.7023, Accuracy: 50.10%
# Iteration 146/10000, Loss: 0.7019, Accuracy: 50.10%
# Iteration 147/10000, Loss: 0.7015, Accuracy: 50.15%
# Iteration 148/10000, Loss: 0.7011, Accuracy: 50.24%
# Iteration 149/10000, Loss: 0.7007, Accuracy: 50.34%
# Iteration 150/10000, Loss: 0.7002, Accuracy: 50.49%
# Iteration 151/10000, Loss: 0.6998, Accuracy: 50.63%
# Iteration 152/10000, Loss: 0.6994, Accuracy: 50.78%
# Iteration 153/10000, Loss: 0.6990, Accuracy: 50.93%
# Iteration 154/10000, Loss: 0.6986, Accuracy: 51.22%
# Iteration 155/10000, Loss: 0.6981, Accuracy: 51.22%
# Iteration 156/10000, Loss: 0.6977, Accuracy: 51.22%
# Iteration 157/10000, Loss: 0.6973, Accuracy: 51.32%
# Iteration 158/10000, Loss: 0.6969, Accuracy: 51.51%
# Iteration 159/10000, Loss: 0.6965, Accuracy: 51.61%
# Iteration 160/10000, Loss: 0.6961, Accuracy: 51.66%
# Iteration 161/10000, Loss: 0.6957, Accuracy: 51.86%
# Iteration 162/10000, Loss: 0.6952, Accuracy: 51.86%
# Iteration 163/10000, Loss: 0.6948, Accuracy: 51.90%
# Iteration 164/10000, Loss: 0.6944, Accuracy: 52.00%
# Iteration 165/10000, Loss: 0.6940, Accuracy: 52.00%
# Iteration 166/10000, Loss: 0.6936, Accuracy: 52.10%
# Iteration 167/10000, Loss: 0.6932, Accuracy: 52.20%
# Iteration 168/10000, Loss: 0.6928, Accuracy: 52.25%
# Iteration 169/10000, Loss: 0.6924, Accuracy: 52.34%
# Iteration 170/10000, Loss: 0.6919, Accuracy: 52.59%
# Iteration 171/10000, Loss: 0.6915, Accuracy: 52.69%
# Iteration 172/10000, Loss: 0.6911, Accuracy: 52.78%
# Iteration 173/10000, Loss: 0.6907, Accuracy: 52.88%
# Iteration 174/10000, Loss: 0.6903, Accuracy: 52.93%
# Iteration 175/10000, Loss: 0.6899, Accuracy: 53.03%
# Iteration 176/10000, Loss: 0.6895, Accuracy: 53.12%
# Iteration 177/10000, Loss: 0.6891, Accuracy: 53.27%
# Iteration 178/10000, Loss: 0.6887, Accuracy: 53.37%
# Iteration 179/10000, Loss: 0.6883, Accuracy: 53.37%
# Iteration 180/10000, Loss: 0.6879, Accuracy: 53.61%
# Iteration 181/10000, Loss: 0.6875, Accuracy: 53.71%
# Iteration 182/10000, Loss: 0.6871, Accuracy: 53.86%
# Iteration 183/10000, Loss: 0.6867, Accuracy: 53.91%
# Iteration 184/10000, Loss: 0.6862, Accuracy: 54.00%
# Iteration 185/10000, Loss: 0.6858, Accuracy: 54.10%
# Iteration 186/10000, Loss: 0.6854, Accuracy: 54.35%
# Iteration 187/10000, Loss: 0.6850, Accuracy: 54.59%
# Iteration 188/10000, Loss: 0.6846, Accuracy: 54.74%
# Iteration 189/10000, Loss: 0.6842, Accuracy: 54.83%
# Iteration 190/10000, Loss: 0.6838, Accuracy: 54.93%
# Iteration 191/10000, Loss: 0.6834, Accuracy: 54.98%
# Iteration 192/10000, Loss: 0.6830, Accuracy: 55.13%
# Iteration 193/10000, Loss: 0.6826, Accuracy: 55.18%
# Iteration 194/10000, Loss: 0.6822, Accuracy: 55.18%
# Iteration 195/10000, Loss: 0.6818, Accuracy: 55.52%
# Iteration 196/10000, Loss: 0.6814, Accuracy: 55.71%
# Iteration 197/10000, Loss: 0.6810, Accuracy: 55.86%
# Iteration 198/10000, Loss: 0.6806, Accuracy: 56.01%
# Iteration 199/10000, Loss: 0.6802, Accuracy: 56.10%
# Iteration 200/10000, Loss: 0.6798, Accuracy: 56.35%
# Iteration 201/10000, Loss: 0.6794, Accuracy: 56.49%
# Iteration 202/10000, Loss: 0.6790, Accuracy: 56.64%
# Iteration 203/10000, Loss: 0.6787, Accuracy: 56.74%
# Iteration 204/10000, Loss: 0.6783, Accuracy: 56.88%
# Iteration 205/10000, Loss: 0.6779, Accuracy: 56.93%
# Iteration 206/10000, Loss: 0.6775, Accuracy: 56.98%
# Iteration 207/10000, Loss: 0.6771, Accuracy: 57.13%
# Iteration 208/10000, Loss: 0.6767, Accuracy: 57.23%
# Iteration 209/10000, Loss: 0.6763, Accuracy: 57.23%
# Iteration 210/10000, Loss: 0.6759, Accuracy: 57.28%
# Iteration 211/10000, Loss: 0.6755, Accuracy: 57.47%
# Iteration 212/10000, Loss: 0.6751, Accuracy: 57.52%
# Iteration 213/10000, Loss: 0.6747, Accuracy: 57.67%
# Iteration 214/10000, Loss: 0.6743, Accuracy: 57.81%
# Iteration 215/10000, Loss: 0.6739, Accuracy: 57.91%
# Iteration 216/10000, Loss: 0.6735, Accuracy: 58.11%
# Iteration 217/10000, Loss: 0.6732, Accuracy: 58.25%
# Iteration 218/10000, Loss: 0.6728, Accuracy: 58.45%
# Iteration 219/10000, Loss: 0.6724, Accuracy: 58.54%
# Iteration 220/10000, Loss: 0.6720, Accuracy: 58.64%
# Iteration 221/10000, Loss: 0.6716, Accuracy: 58.69%
# Iteration 222/10000, Loss: 0.6712, Accuracy: 58.89%
# Iteration 223/10000, Loss: 0.6708, Accuracy: 58.94%
# Iteration 224/10000, Loss: 0.6704, Accuracy: 59.03%
# Iteration 225/10000, Loss: 0.6700, Accuracy: 59.08%
# Iteration 226/10000, Loss: 0.6697, Accuracy: 59.18%
# Iteration 227/10000, Loss: 0.6693, Accuracy: 59.23%
# Iteration 228/10000, Loss: 0.6689, Accuracy: 59.42%
# Iteration 229/10000, Loss: 0.6685, Accuracy: 59.57%
# Iteration 230/10000, Loss: 0.6681, Accuracy: 59.62%
# Iteration 231/10000, Loss: 0.6677, Accuracy: 59.77%
# Iteration 232/10000, Loss: 0.6673, Accuracy: 59.86%
# Iteration 233/10000, Loss: 0.6670, Accuracy: 59.91%
# Iteration 234/10000, Loss: 0.6666, Accuracy: 60.06%
# Iteration 235/10000, Loss: 0.6662, Accuracy: 60.25%
# Iteration 236/10000, Loss: 0.6658, Accuracy: 60.30%
# Iteration 237/10000, Loss: 0.6654, Accuracy: 60.45%
# Iteration 238/10000, Loss: 0.6651, Accuracy: 60.55%
# Iteration 239/10000, Loss: 0.6647, Accuracy: 60.64%
# Iteration 240/10000, Loss: 0.6643, Accuracy: 60.89%
# Iteration 241/10000, Loss: 0.6639, Accuracy: 60.99%
# Iteration 242/10000, Loss: 0.6635, Accuracy: 61.18%
# Iteration 243/10000, Loss: 0.6632, Accuracy: 61.28%
# Iteration 244/10000, Loss: 0.6628, Accuracy: 61.38%
# Iteration 245/10000, Loss: 0.6624, Accuracy: 61.52%
# Iteration 246/10000, Loss: 0.6620, Accuracy: 61.72%
# Iteration 247/10000, Loss: 0.6616, Accuracy: 61.77%
# Iteration 248/10000, Loss: 0.6613, Accuracy: 61.91%
# Iteration 249/10000, Loss: 0.6609, Accuracy: 62.06%
# Iteration 250/10000, Loss: 0.6605, Accuracy: 62.11%
# Iteration 251/10000, Loss: 0.6601, Accuracy: 62.11%
# Iteration 252/10000, Loss: 0.6598, Accuracy: 62.21%
# Iteration 253/10000, Loss: 0.6594, Accuracy: 62.40%
# Iteration 254/10000, Loss: 0.6590, Accuracy: 62.55%
# Iteration 255/10000, Loss: 0.6586, Accuracy: 62.74%
# Iteration 256/10000, Loss: 0.6583, Accuracy: 62.99%
# Iteration 257/10000, Loss: 0.6579, Accuracy: 62.99%
# Iteration 258/10000, Loss: 0.6575, Accuracy: 63.09%
# Iteration 259/10000, Loss: 0.6571, Accuracy: 63.18%
# Iteration 260/10000, Loss: 0.6568, Accuracy: 63.18%
# Iteration 261/10000, Loss: 0.6564, Accuracy: 63.28%
# Iteration 262/10000, Loss: 0.6560, Accuracy: 63.38%
# Iteration 263/10000, Loss: 0.6556, Accuracy: 63.43%
# Iteration 264/10000, Loss: 0.6553, Accuracy: 63.48%
# Iteration 265/10000, Loss: 0.6549, Accuracy: 63.53%
# Iteration 266/10000, Loss: 0.6545, Accuracy: 63.62%
# Iteration 267/10000, Loss: 0.6542, Accuracy: 63.72%
# Iteration 268/10000, Loss: 0.6538, Accuracy: 63.77%
# Iteration 269/10000, Loss: 0.6534, Accuracy: 63.92%
# Iteration 270/10000, Loss: 0.6531, Accuracy: 63.96%
# Iteration 271/10000, Loss: 0.6527, Accuracy: 64.06%
# Iteration 272/10000, Loss: 0.6523, Accuracy: 64.21%
# Iteration 273/10000, Loss: 0.6520, Accuracy: 64.26%
# Iteration 274/10000, Loss: 0.6516, Accuracy: 64.31%
# Iteration 275/10000, Loss: 0.6512, Accuracy: 64.36%
# Iteration 276/10000, Loss: 0.6509, Accuracy: 64.45%
# Iteration 277/10000, Loss: 0.6505, Accuracy: 64.60%
# Iteration 278/10000, Loss: 0.6501, Accuracy: 64.65%
# Iteration 279/10000, Loss: 0.6498, Accuracy: 64.75%
# Iteration 280/10000, Loss: 0.6494, Accuracy: 64.94%
# Iteration 281/10000, Loss: 0.6490, Accuracy: 64.99%
# Iteration 282/10000, Loss: 0.6487, Accuracy: 65.09%
# Iteration 283/10000, Loss: 0.6483, Accuracy: 65.28%
# Iteration 284/10000, Loss: 0.6479, Accuracy: 65.33%
# Iteration 285/10000, Loss: 0.6476, Accuracy: 65.38%
# Iteration 286/10000, Loss: 0.6472, Accuracy: 65.53%
# Iteration 287/10000, Loss: 0.6468, Accuracy: 65.62%
# Iteration 288/10000, Loss: 0.6465, Accuracy: 65.77%
# Iteration 289/10000, Loss: 0.6461, Accuracy: 65.82%
# Iteration 290/10000, Loss: 0.6458, Accuracy: 65.92%
# Iteration 291/10000, Loss: 0.6454, Accuracy: 66.02%
# Iteration 292/10000, Loss: 0.6450, Accuracy: 66.06%
# Iteration 293/10000, Loss: 0.6447, Accuracy: 66.16%
# Iteration 294/10000, Loss: 0.6443, Accuracy: 66.16%
# Iteration 295/10000, Loss: 0.6440, Accuracy: 66.26%
# Iteration 296/10000, Loss: 0.6436, Accuracy: 66.46%
# Iteration 297/10000, Loss: 0.6432, Accuracy: 66.55%
# Iteration 298/10000, Loss: 0.6429, Accuracy: 66.60%
# Iteration 299/10000, Loss: 0.6425, Accuracy: 66.65%
# Iteration 300/10000, Loss: 0.6422, Accuracy: 66.70%
# Iteration 301/10000, Loss: 0.6418, Accuracy: 66.85%
# Iteration 302/10000, Loss: 0.6415, Accuracy: 66.85%
# Iteration 303/10000, Loss: 0.6411, Accuracy: 66.89%
# Iteration 304/10000, Loss: 0.6407, Accuracy: 66.94%
# Iteration 305/10000, Loss: 0.6404, Accuracy: 67.04%
# Iteration 306/10000, Loss: 0.6400, Accuracy: 67.09%
# Iteration 307/10000, Loss: 0.6397, Accuracy: 67.24%
# Iteration 308/10000, Loss: 0.6393, Accuracy: 67.33%
# Iteration 309/10000, Loss: 0.6390, Accuracy: 67.38%
# Iteration 310/10000, Loss: 0.6386, Accuracy: 67.53%
# Iteration 311/10000, Loss: 0.6383, Accuracy: 67.63%
# Iteration 312/10000, Loss: 0.6379, Accuracy: 67.82%
# Iteration 313/10000, Loss: 0.6376, Accuracy: 67.87%
# Iteration 314/10000, Loss: 0.6372, Accuracy: 67.92%
# Iteration 315/10000, Loss: 0.6369, Accuracy: 67.92%
# Iteration 316/10000, Loss: 0.6365, Accuracy: 68.02%
# Iteration 317/10000, Loss: 0.6362, Accuracy: 68.16%
# Iteration 318/10000, Loss: 0.6358, Accuracy: 68.31%
# Iteration 319/10000, Loss: 0.6355, Accuracy: 68.41%
# Iteration 320/10000, Loss: 0.6351, Accuracy: 68.51%
# Iteration 321/10000, Loss: 0.6348, Accuracy: 68.55%
# Iteration 322/10000, Loss: 0.6344, Accuracy: 68.70%
# Iteration 323/10000, Loss: 0.6341, Accuracy: 68.75%
# Iteration 324/10000, Loss: 0.6337, Accuracy: 68.99%
# Iteration 325/10000, Loss: 0.6334, Accuracy: 69.09%
# Iteration 326/10000, Loss: 0.6330, Accuracy: 69.14%
# Iteration 327/10000, Loss: 0.6327, Accuracy: 69.14%
# Iteration 328/10000, Loss: 0.6323, Accuracy: 69.19%
# Iteration 329/10000, Loss: 0.6320, Accuracy: 69.34%
# Iteration 330/10000, Loss: 0.6316, Accuracy: 69.43%
# Iteration 331/10000, Loss: 0.6313, Accuracy: 69.48%
# Iteration 332/10000, Loss: 0.6309, Accuracy: 69.48%
# Iteration 333/10000, Loss: 0.6306, Accuracy: 69.53%
# Iteration 334/10000, Loss: 0.6303, Accuracy: 69.73%
# Iteration 335/10000, Loss: 0.6299, Accuracy: 69.78%
# Iteration 336/10000, Loss: 0.6296, Accuracy: 69.87%
# Iteration 337/10000, Loss: 0.6292, Accuracy: 70.07%
# Iteration 338/10000, Loss: 0.6289, Accuracy: 70.26%
# Iteration 339/10000, Loss: 0.6285, Accuracy: 70.31%
# Iteration 340/10000, Loss: 0.6282, Accuracy: 70.41%
# Iteration 341/10000, Loss: 0.6279, Accuracy: 70.51%
# Iteration 342/10000, Loss: 0.6275, Accuracy: 70.56%
# Iteration 343/10000, Loss: 0.6272, Accuracy: 70.65%
# Iteration 344/10000, Loss: 0.6268, Accuracy: 70.75%
# Iteration 345/10000, Loss: 0.6265, Accuracy: 70.85%
# Iteration 346/10000, Loss: 0.6261, Accuracy: 70.85%
# Iteration 347/10000, Loss: 0.6258, Accuracy: 70.95%
# Iteration 348/10000, Loss: 0.6255, Accuracy: 71.00%
# Iteration 349/10000, Loss: 0.6251, Accuracy: 71.00%
# Iteration 350/10000, Loss: 0.6248, Accuracy: 71.04%
# Iteration 351/10000, Loss: 0.6245, Accuracy: 71.04%
# Iteration 352/10000, Loss: 0.6241, Accuracy: 71.09%
# Iteration 353/10000, Loss: 0.6238, Accuracy: 71.24%
# Iteration 354/10000, Loss: 0.6234, Accuracy: 71.29%
# Iteration 355/10000, Loss: 0.6231, Accuracy: 71.39%
# Iteration 356/10000, Loss: 0.6228, Accuracy: 71.39%
# Iteration 357/10000, Loss: 0.6224, Accuracy: 71.58%
# Iteration 358/10000, Loss: 0.6221, Accuracy: 71.58%
# Iteration 359/10000, Loss: 0.6218, Accuracy: 71.53%
# Iteration 360/10000, Loss: 0.6214, Accuracy: 71.53%
# Iteration 361/10000, Loss: 0.6211, Accuracy: 71.63%
# Iteration 362/10000, Loss: 0.6208, Accuracy: 71.73%
# Iteration 363/10000, Loss: 0.6204, Accuracy: 71.78%
# Iteration 364/10000, Loss: 0.6201, Accuracy: 71.83%
# Iteration 365/10000, Loss: 0.6197, Accuracy: 71.83%
# Iteration 366/10000, Loss: 0.6194, Accuracy: 71.97%
# Iteration 367/10000, Loss: 0.6191, Accuracy: 72.17%
# Iteration 368/10000, Loss: 0.6188, Accuracy: 72.22%
# Iteration 369/10000, Loss: 0.6184, Accuracy: 72.31%
# Iteration 370/10000, Loss: 0.6181, Accuracy: 72.31%
# Iteration 371/10000, Loss: 0.6178, Accuracy: 72.36%
# Iteration 372/10000, Loss: 0.6174, Accuracy: 72.56%
# Iteration 373/10000, Loss: 0.6171, Accuracy: 72.66%
# Iteration 374/10000, Loss: 0.6168, Accuracy: 72.75%
# Iteration 375/10000, Loss: 0.6164, Accuracy: 72.75%
# Iteration 376/10000, Loss: 0.6161, Accuracy: 72.75%
# Iteration 377/10000, Loss: 0.6158, Accuracy: 72.85%
# Iteration 378/10000, Loss: 0.6154, Accuracy: 72.90%
# Iteration 379/10000, Loss: 0.6151, Accuracy: 72.95%
# Iteration 380/10000, Loss: 0.6148, Accuracy: 73.00%
# Iteration 381/10000, Loss: 0.6145, Accuracy: 73.00%
# Iteration 382/10000, Loss: 0.6141, Accuracy: 73.05%
# Iteration 383/10000, Loss: 0.6138, Accuracy: 73.10%
# Iteration 384/10000, Loss: 0.6135, Accuracy: 73.24%
# Iteration 385/10000, Loss: 0.6132, Accuracy: 73.29%
# Iteration 386/10000, Loss: 0.6128, Accuracy: 73.39%
# Iteration 387/10000, Loss: 0.6125, Accuracy: 73.54%
# Iteration 388/10000, Loss: 0.6122, Accuracy: 73.58%
# Iteration 389/10000, Loss: 0.6119, Accuracy: 73.58%
# Iteration 390/10000, Loss: 0.6115, Accuracy: 73.63%
# Iteration 391/10000, Loss: 0.6112, Accuracy: 73.68%
# Iteration 392/10000, Loss: 0.6109, Accuracy: 73.83%
# Iteration 393/10000, Loss: 0.6106, Accuracy: 73.93%
# Iteration 394/10000, Loss: 0.6102, Accuracy: 74.02%
# Iteration 395/10000, Loss: 0.6099, Accuracy: 74.17%
# Iteration 396/10000, Loss: 0.6096, Accuracy: 74.32%
# Iteration 397/10000, Loss: 0.6093, Accuracy: 74.41%
# Iteration 398/10000, Loss: 0.6089, Accuracy: 74.46%
# Iteration 399/10000, Loss: 0.6086, Accuracy: 74.51%
# Iteration 400/10000, Loss: 0.6083, Accuracy: 74.56%
# Iteration 401/10000, Loss: 0.6080, Accuracy: 74.66%
# Iteration 402/10000, Loss: 0.6077, Accuracy: 74.76%
# Iteration 403/10000, Loss: 0.6073, Accuracy: 74.80%
# Iteration 404/10000, Loss: 0.6070, Accuracy: 74.95%
# Iteration 405/10000, Loss: 0.6067, Accuracy: 75.05%
# Iteration 406/10000, Loss: 0.6064, Accuracy: 75.10%
# Iteration 407/10000, Loss: 0.6061, Accuracy: 75.15%
# Iteration 408/10000, Loss: 0.6057, Accuracy: 75.15%
# Iteration 409/10000, Loss: 0.6054, Accuracy: 75.24%
# Iteration 410/10000, Loss: 0.6051, Accuracy: 75.24%
# Iteration 411/10000, Loss: 0.6048, Accuracy: 75.44%
# Iteration 412/10000, Loss: 0.6045, Accuracy: 75.49%
# Iteration 413/10000, Loss: 0.6042, Accuracy: 75.49%
# Iteration 414/10000, Loss: 0.6038, Accuracy: 75.54%
# Iteration 415/10000, Loss: 0.6035, Accuracy: 75.54%
# Iteration 416/10000, Loss: 0.6032, Accuracy: 75.54%
# Iteration 417/10000, Loss: 0.6029, Accuracy: 75.63%
# Iteration 418/10000, Loss: 0.6026, Accuracy: 75.78%
# Iteration 419/10000, Loss: 0.6023, Accuracy: 75.83%
# Iteration 420/10000, Loss: 0.6019, Accuracy: 75.93%
# Iteration 421/10000, Loss: 0.6016, Accuracy: 75.93%
# Iteration 422/10000, Loss: 0.6013, Accuracy: 76.03%
# Iteration 423/10000, Loss: 0.6010, Accuracy: 76.03%
# Iteration 424/10000, Loss: 0.6007, Accuracy: 75.98%
# Iteration 425/10000, Loss: 0.6004, Accuracy: 75.98%
# Iteration 426/10000, Loss: 0.6001, Accuracy: 76.03%
# Iteration 427/10000, Loss: 0.5997, Accuracy: 76.27%
# Iteration 428/10000, Loss: 0.5994, Accuracy: 76.37%
# Iteration 429/10000, Loss: 0.5991, Accuracy: 76.42%
# Iteration 430/10000, Loss: 0.5988, Accuracy: 76.56%
# Iteration 431/10000, Loss: 0.5985, Accuracy: 76.56%
# Iteration 432/10000, Loss: 0.5982, Accuracy: 76.56%
# Iteration 433/10000, Loss: 0.5979, Accuracy: 76.66%
# Iteration 434/10000, Loss: 0.5976, Accuracy: 76.71%
# Iteration 435/10000, Loss: 0.5973, Accuracy: 76.71%
# Iteration 436/10000, Loss: 0.5969, Accuracy: 76.81%
# Iteration 437/10000, Loss: 0.5966, Accuracy: 76.95%
# Iteration 438/10000, Loss: 0.5963, Accuracy: 77.00%
# Iteration 439/10000, Loss: 0.5960, Accuracy: 77.15%
# Iteration 440/10000, Loss: 0.5957, Accuracy: 77.20%
# Iteration 441/10000, Loss: 0.5954, Accuracy: 77.34%
# Iteration 442/10000, Loss: 0.5951, Accuracy: 77.39%
# Iteration 443/10000, Loss: 0.5948, Accuracy: 77.39%
# Iteration 444/10000, Loss: 0.5945, Accuracy: 77.69%
# Iteration 445/10000, Loss: 0.5942, Accuracy: 77.93%
# Iteration 446/10000, Loss: 0.5939, Accuracy: 78.03%
# Iteration 447/10000, Loss: 0.5936, Accuracy: 78.08%
# Iteration 448/10000, Loss: 0.5933, Accuracy: 78.12%
# Iteration 449/10000, Loss: 0.5930, Accuracy: 78.12%
# Iteration 450/10000, Loss: 0.5927, Accuracy: 78.37%
# Iteration 451/10000, Loss: 0.5923, Accuracy: 78.37%
# Iteration 452/10000, Loss: 0.5920, Accuracy: 78.42%
# Iteration 453/10000, Loss: 0.5917, Accuracy: 78.42%
# Iteration 454/10000, Loss: 0.5914, Accuracy: 78.47%
# Iteration 455/10000, Loss: 0.5911, Accuracy: 78.61%
# Iteration 456/10000, Loss: 0.5908, Accuracy: 78.81%
# Iteration 457/10000, Loss: 0.5905, Accuracy: 78.81%
# Iteration 458/10000, Loss: 0.5902, Accuracy: 78.91%
# Iteration 459/10000, Loss: 0.5899, Accuracy: 78.91%
# Iteration 460/10000, Loss: 0.5896, Accuracy: 79.10%
# Iteration 461/10000, Loss: 0.5893, Accuracy: 79.30%
# Iteration 462/10000, Loss: 0.5890, Accuracy: 79.35%
# Iteration 463/10000, Loss: 0.5887, Accuracy: 79.39%
# Iteration 464/10000, Loss: 0.5884, Accuracy: 79.49%
# Iteration 465/10000, Loss: 0.5881, Accuracy: 79.49%
# Iteration 466/10000, Loss: 0.5878, Accuracy: 79.49%
# Iteration 467/10000, Loss: 0.5875, Accuracy: 79.49%
# Iteration 468/10000, Loss: 0.5872, Accuracy: 79.54%
# Iteration 469/10000, Loss: 0.5869, Accuracy: 79.59%
# Iteration 470/10000, Loss: 0.5866, Accuracy: 79.59%
# Iteration 471/10000, Loss: 0.5863, Accuracy: 79.79%
# Iteration 472/10000, Loss: 0.5860, Accuracy: 79.83%
# Iteration 473/10000, Loss: 0.5857, Accuracy: 79.83%
# Iteration 474/10000, Loss: 0.5854, Accuracy: 79.93%
# Iteration 475/10000, Loss: 0.5851, Accuracy: 79.93%
# Iteration 476/10000, Loss: 0.5848, Accuracy: 79.98%
# Iteration 477/10000, Loss: 0.5845, Accuracy: 80.03%
# Iteration 478/10000, Loss: 0.5842, Accuracy: 80.13%
# Iteration 479/10000, Loss: 0.5839, Accuracy: 80.13%
# Iteration 480/10000, Loss: 0.5836, Accuracy: 80.18%
# Iteration 481/10000, Loss: 0.5834, Accuracy: 80.22%
# Iteration 482/10000, Loss: 0.5831, Accuracy: 80.22%
# Iteration 483/10000, Loss: 0.5828, Accuracy: 80.27%
# Iteration 484/10000, Loss: 0.5825, Accuracy: 80.32%
# Iteration 485/10000, Loss: 0.5822, Accuracy: 80.47%
# Iteration 486/10000, Loss: 0.5819, Accuracy: 80.47%
# Iteration 487/10000, Loss: 0.5816, Accuracy: 80.62%
# Iteration 488/10000, Loss: 0.5813, Accuracy: 80.66%
# Iteration 489/10000, Loss: 0.5810, Accuracy: 80.71%
# Iteration 490/10000, Loss: 0.5807, Accuracy: 80.81%
# Iteration 491/10000, Loss: 0.5804, Accuracy: 80.91%
# Iteration 492/10000, Loss: 0.5801, Accuracy: 80.96%
# Iteration 493/10000, Loss: 0.5798, Accuracy: 81.05%
# Iteration 494/10000, Loss: 0.5795, Accuracy: 81.05%
# Iteration 495/10000, Loss: 0.5792, Accuracy: 81.15%
# Iteration 496/10000, Loss: 0.5790, Accuracy: 81.25%
# Iteration 497/10000, Loss: 0.5787, Accuracy: 81.35%
# Iteration 498/10000, Loss: 0.5784, Accuracy: 81.40%
# Iteration 499/10000, Loss: 0.5781, Accuracy: 81.49%
# Iteration 500/10000, Loss: 0.5778, Accuracy: 81.64%
# Iteration 501/10000, Loss: 0.5775, Accuracy: 81.64%
# Iteration 502/10000, Loss: 0.5772, Accuracy: 81.69%
# Iteration 503/10000, Loss: 0.5769, Accuracy: 81.69%
# Iteration 504/10000, Loss: 0.5766, Accuracy: 81.74%
# Iteration 505/10000, Loss: 0.5764, Accuracy: 81.79%
# Iteration 506/10000, Loss: 0.5761, Accuracy: 81.79%
# Iteration 507/10000, Loss: 0.5758, Accuracy: 81.84%
# Iteration 508/10000, Loss: 0.5755, Accuracy: 81.93%
# Iteration 509/10000, Loss: 0.5752, Accuracy: 81.98%
# Iteration 510/10000, Loss: 0.5749, Accuracy: 82.03%
# Iteration 511/10000, Loss: 0.5746, Accuracy: 82.08%
# Iteration 512/10000, Loss: 0.5743, Accuracy: 82.08%
# Iteration 513/10000, Loss: 0.5741, Accuracy: 82.08%
# Iteration 514/10000, Loss: 0.5738, Accuracy: 82.08%
# Iteration 515/10000, Loss: 0.5735, Accuracy: 82.08%
# Iteration 516/10000, Loss: 0.5732, Accuracy: 82.13%
# Iteration 517/10000, Loss: 0.5729, Accuracy: 82.28%
# Iteration 518/10000, Loss: 0.5726, Accuracy: 82.28%
# Iteration 519/10000, Loss: 0.5724, Accuracy: 82.32%
# Iteration 520/10000, Loss: 0.5721, Accuracy: 82.32%
# Iteration 521/10000, Loss: 0.5718, Accuracy: 82.32%
# Iteration 522/10000, Loss: 0.5715, Accuracy: 82.32%
# Iteration 523/10000, Loss: 0.5712, Accuracy: 82.42%
# Iteration 524/10000, Loss: 0.5709, Accuracy: 82.47%
# Iteration 525/10000, Loss: 0.5707, Accuracy: 82.52%
# Iteration 526/10000, Loss: 0.5704, Accuracy: 82.62%
# Iteration 527/10000, Loss: 0.5701, Accuracy: 82.76%
# Iteration 528/10000, Loss: 0.5698, Accuracy: 82.81%
# Iteration 529/10000, Loss: 0.5695, Accuracy: 82.81%
# Iteration 530/10000, Loss: 0.5692, Accuracy: 82.91%
# Iteration 531/10000, Loss: 0.5690, Accuracy: 82.96%
# Iteration 532/10000, Loss: 0.5687, Accuracy: 83.01%
# Iteration 533/10000, Loss: 0.5684, Accuracy: 83.15%
# Iteration 534/10000, Loss: 0.5681, Accuracy: 83.20%
# Iteration 535/10000, Loss: 0.5678, Accuracy: 83.25%
# Iteration 536/10000, Loss: 0.5676, Accuracy: 83.30%
# Iteration 537/10000, Loss: 0.5673, Accuracy: 83.40%
# Iteration 538/10000, Loss: 0.5670, Accuracy: 83.40%
# Iteration 539/10000, Loss: 0.5667, Accuracy: 83.45%
# Iteration 540/10000, Loss: 0.5665, Accuracy: 83.59%
# Iteration 541/10000, Loss: 0.5662, Accuracy: 83.69%
# Iteration 542/10000, Loss: 0.5659, Accuracy: 83.69%
# Iteration 543/10000, Loss: 0.5656, Accuracy: 83.74%
# Iteration 544/10000, Loss: 0.5653, Accuracy: 83.79%
# Iteration 545/10000, Loss: 0.5651, Accuracy: 83.89%
# Iteration 546/10000, Loss: 0.5648, Accuracy: 84.03%
# Iteration 547/10000, Loss: 0.5645, Accuracy: 84.13%
# Iteration 548/10000, Loss: 0.5642, Accuracy: 84.28%
# Iteration 549/10000, Loss: 0.5640, Accuracy: 84.33%
# Iteration 550/10000, Loss: 0.5637, Accuracy: 84.38%
# Iteration 551/10000, Loss: 0.5634, Accuracy: 84.42%
# Iteration 552/10000, Loss: 0.5631, Accuracy: 84.52%
# Iteration 553/10000, Loss: 0.5629, Accuracy: 84.52%
# Iteration 554/10000, Loss: 0.5626, Accuracy: 84.57%
# Iteration 555/10000, Loss: 0.5623, Accuracy: 84.62%
# Iteration 556/10000, Loss: 0.5620, Accuracy: 84.67%
# Iteration 557/10000, Loss: 0.5618, Accuracy: 84.72%
# Iteration 558/10000, Loss: 0.5615, Accuracy: 84.81%
# Iteration 559/10000, Loss: 0.5612, Accuracy: 84.86%
# Iteration 560/10000, Loss: 0.5610, Accuracy: 85.01%
# Iteration 561/10000, Loss: 0.5607, Accuracy: 84.96%
# Iteration 562/10000, Loss: 0.5604, Accuracy: 84.96%
# Iteration 563/10000, Loss: 0.5601, Accuracy: 85.01%
# Iteration 564/10000, Loss: 0.5599, Accuracy: 85.11%
# Iteration 565/10000, Loss: 0.5596, Accuracy: 85.11%
# Iteration 566/10000, Loss: 0.5593, Accuracy: 85.11%
# Iteration 567/10000, Loss: 0.5591, Accuracy: 85.16%
# Iteration 568/10000, Loss: 0.5588, Accuracy: 85.25%
# Iteration 569/10000, Loss: 0.5585, Accuracy: 85.30%
# Iteration 570/10000, Loss: 0.5582, Accuracy: 85.40%
# Iteration 571/10000, Loss: 0.5580, Accuracy: 85.40%
# Iteration 572/10000, Loss: 0.5577, Accuracy: 85.45%
# Iteration 573/10000, Loss: 0.5574, Accuracy: 85.45%
# Iteration 574/10000, Loss: 0.5572, Accuracy: 85.45%
# Iteration 575/10000, Loss: 0.5569, Accuracy: 85.45%
# Iteration 576/10000, Loss: 0.5566, Accuracy: 85.45%
# Iteration 577/10000, Loss: 0.5564, Accuracy: 85.45%
# Iteration 578/10000, Loss: 0.5561, Accuracy: 85.45%
# Iteration 579/10000, Loss: 0.5558, Accuracy: 85.60%
# Iteration 580/10000, Loss: 0.5556, Accuracy: 85.74%
# Iteration 581/10000, Loss: 0.5553, Accuracy: 85.74%
# Iteration 582/10000, Loss: 0.5550, Accuracy: 85.79%
# Iteration 583/10000, Loss: 0.5548, Accuracy: 85.79%
# Iteration 584/10000, Loss: 0.5545, Accuracy: 85.79%
# Iteration 585/10000, Loss: 0.5542, Accuracy: 85.79%
# Iteration 586/10000, Loss: 0.5540, Accuracy: 85.79%
# Iteration 587/10000, Loss: 0.5537, Accuracy: 85.79%
# Iteration 588/10000, Loss: 0.5534, Accuracy: 85.79%
# Iteration 589/10000, Loss: 0.5532, Accuracy: 85.99%
# Iteration 590/10000, Loss: 0.5529, Accuracy: 86.04%
# Iteration 591/10000, Loss: 0.5526, Accuracy: 86.04%
# Iteration 592/10000, Loss: 0.5524, Accuracy: 86.04%
# Iteration 593/10000, Loss: 0.5521, Accuracy: 86.04%
# Iteration 594/10000, Loss: 0.5519, Accuracy: 86.08%
# Iteration 595/10000, Loss: 0.5516, Accuracy: 86.08%
# Iteration 596/10000, Loss: 0.5513, Accuracy: 86.13%
# Iteration 597/10000, Loss: 0.5511, Accuracy: 86.18%
# Iteration 598/10000, Loss: 0.5508, Accuracy: 86.23%
# Iteration 599/10000, Loss: 0.5505, Accuracy: 86.28%
# Iteration 600/10000, Loss: 0.5503, Accuracy: 86.33%
# Iteration 601/10000, Loss: 0.5500, Accuracy: 86.33%
# Iteration 602/10000, Loss: 0.5498, Accuracy: 86.33%
# Iteration 603/10000, Loss: 0.5495, Accuracy: 86.38%
# Iteration 604/10000, Loss: 0.5492, Accuracy: 86.38%
# Iteration 605/10000, Loss: 0.5490, Accuracy: 86.52%
# Iteration 606/10000, Loss: 0.5487, Accuracy: 86.52%
# Iteration 607/10000, Loss: 0.5485, Accuracy: 86.52%
# Iteration 608/10000, Loss: 0.5482, Accuracy: 86.52%
# Iteration 609/10000, Loss: 0.5479, Accuracy: 86.57%
# Iteration 610/10000, Loss: 0.5477, Accuracy: 86.57%
# Iteration 611/10000, Loss: 0.5474, Accuracy: 86.67%
# Iteration 612/10000, Loss: 0.5472, Accuracy: 86.67%
# Iteration 613/10000, Loss: 0.5469, Accuracy: 86.72%
# Iteration 614/10000, Loss: 0.5467, Accuracy: 86.72%
# Iteration 615/10000, Loss: 0.5464, Accuracy: 86.82%
# Iteration 616/10000, Loss: 0.5461, Accuracy: 86.87%
# Iteration 617/10000, Loss: 0.5459, Accuracy: 86.87%
# Iteration 618/10000, Loss: 0.5456, Accuracy: 86.91%
# Iteration 619/10000, Loss: 0.5454, Accuracy: 86.96%
# Iteration 620/10000, Loss: 0.5451, Accuracy: 86.96%
# Iteration 621/10000, Loss: 0.5449, Accuracy: 87.01%
# Iteration 622/10000, Loss: 0.5446, Accuracy: 87.06%
# Iteration 623/10000, Loss: 0.5443, Accuracy: 87.01%
# Iteration 624/10000, Loss: 0.5441, Accuracy: 87.01%
# Iteration 625/10000, Loss: 0.5438, Accuracy: 87.01%
# Iteration 626/10000, Loss: 0.5436, Accuracy: 87.06%
# Iteration 627/10000, Loss: 0.5433, Accuracy: 87.06%
# Iteration 628/10000, Loss: 0.5431, Accuracy: 87.06%
# Iteration 629/10000, Loss: 0.5428, Accuracy: 87.16%
# Iteration 630/10000, Loss: 0.5426, Accuracy: 87.16%
# Iteration 631/10000, Loss: 0.5423, Accuracy: 87.16%
# Iteration 632/10000, Loss: 0.5421, Accuracy: 87.26%
# Iteration 633/10000, Loss: 0.5418, Accuracy: 87.26%
# Iteration 634/10000, Loss: 0.5416, Accuracy: 87.35%
# Iteration 635/10000, Loss: 0.5413, Accuracy: 87.40%
# Iteration 636/10000, Loss: 0.5410, Accuracy: 87.40%
# Iteration 637/10000, Loss: 0.5408, Accuracy: 87.45%
# Iteration 638/10000, Loss: 0.5405, Accuracy: 87.45%
# Iteration 639/10000, Loss: 0.5403, Accuracy: 87.50%
# Iteration 640/10000, Loss: 0.5400, Accuracy: 87.60%
# Iteration 641/10000, Loss: 0.5398, Accuracy: 87.60%
# Iteration 642/10000, Loss: 0.5395, Accuracy: 87.60%
# Iteration 643/10000, Loss: 0.5393, Accuracy: 87.65%
# Iteration 644/10000, Loss: 0.5390, Accuracy: 87.74%
# Iteration 645/10000, Loss: 0.5388, Accuracy: 87.84%
# Iteration 646/10000, Loss: 0.5385, Accuracy: 87.89%
# Iteration 647/10000, Loss: 0.5383, Accuracy: 87.94%
# Iteration 648/10000, Loss: 0.5380, Accuracy: 87.99%
# Iteration 649/10000, Loss: 0.5378, Accuracy: 87.99%
# Iteration 650/10000, Loss: 0.5375, Accuracy: 87.99%
# Iteration 651/10000, Loss: 0.5373, Accuracy: 88.04%
# Iteration 652/10000, Loss: 0.5370, Accuracy: 88.04%
# Iteration 653/10000, Loss: 0.5368, Accuracy: 88.09%
# Iteration 654/10000, Loss: 0.5366, Accuracy: 88.09%
# Iteration 655/10000, Loss: 0.5363, Accuracy: 88.09%
# Iteration 656/10000, Loss: 0.5361, Accuracy: 88.13%
# Iteration 657/10000, Loss: 0.5358, Accuracy: 88.13%
# Iteration 658/10000, Loss: 0.5356, Accuracy: 88.13%
# Iteration 659/10000, Loss: 0.5353, Accuracy: 88.18%
# Iteration 660/10000, Loss: 0.5351, Accuracy: 88.23%
# Iteration 661/10000, Loss: 0.5348, Accuracy: 88.23%
# Iteration 662/10000, Loss: 0.5346, Accuracy: 88.28%
# Iteration 663/10000, Loss: 0.5343, Accuracy: 88.28%
# Iteration 664/10000, Loss: 0.5341, Accuracy: 88.28%
# Iteration 665/10000, Loss: 0.5338, Accuracy: 88.33%
# Iteration 666/10000, Loss: 0.5336, Accuracy: 88.33%
# Iteration 667/10000, Loss: 0.5334, Accuracy: 88.33%
# Iteration 668/10000, Loss: 0.5331, Accuracy: 88.33%
# Iteration 669/10000, Loss: 0.5329, Accuracy: 88.33%
# Iteration 670/10000, Loss: 0.5326, Accuracy: 88.33%
# Iteration 671/10000, Loss: 0.5324, Accuracy: 88.33%
# Iteration 672/10000, Loss: 0.5321, Accuracy: 88.38%
# Iteration 673/10000, Loss: 0.5319, Accuracy: 88.38%
# Iteration 674/10000, Loss: 0.5316, Accuracy: 88.38%
# Iteration 675/10000, Loss: 0.5314, Accuracy: 88.38%
# Iteration 676/10000, Loss: 0.5312, Accuracy: 88.48%
# Iteration 677/10000, Loss: 0.5309, Accuracy: 88.48%
# Iteration 678/10000, Loss: 0.5307, Accuracy: 88.48%
# Iteration 679/10000, Loss: 0.5304, Accuracy: 88.48%
# Iteration 680/10000, Loss: 0.5302, Accuracy: 88.48%
# Iteration 681/10000, Loss: 0.5300, Accuracy: 88.48%
# Iteration 682/10000, Loss: 0.5297, Accuracy: 88.48%
# Iteration 683/10000, Loss: 0.5295, Accuracy: 88.48%
# Iteration 684/10000, Loss: 0.5292, Accuracy: 88.53%
# Iteration 685/10000, Loss: 0.5290, Accuracy: 88.53%
# Iteration 686/10000, Loss: 0.5288, Accuracy: 88.62%
# Iteration 687/10000, Loss: 0.5285, Accuracy: 88.67%
# Iteration 688/10000, Loss: 0.5283, Accuracy: 88.72%
# Iteration 689/10000, Loss: 0.5280, Accuracy: 88.77%
# Iteration 690/10000, Loss: 0.5278, Accuracy: 88.77%
# Iteration 691/10000, Loss: 0.5276, Accuracy: 88.82%
# Iteration 692/10000, Loss: 0.5273, Accuracy: 88.82%
# Iteration 693/10000, Loss: 0.5271, Accuracy: 88.82%
# Iteration 694/10000, Loss: 0.5268, Accuracy: 88.82%
# Iteration 695/10000, Loss: 0.5266, Accuracy: 88.92%
# Iteration 696/10000, Loss: 0.5264, Accuracy: 88.92%
# Iteration 697/10000, Loss: 0.5261, Accuracy: 88.92%
# Iteration 698/10000, Loss: 0.5259, Accuracy: 88.92%
# Iteration 699/10000, Loss: 0.5257, Accuracy: 89.01%
# Iteration 700/10000, Loss: 0.5254, Accuracy: 89.01%
# Iteration 701/10000, Loss: 0.5252, Accuracy: 89.01%
# Iteration 702/10000, Loss: 0.5249, Accuracy: 89.01%
# Iteration 703/10000, Loss: 0.5247, Accuracy: 89.01%
# Iteration 704/10000, Loss: 0.5245, Accuracy: 89.01%
# Iteration 705/10000, Loss: 0.5242, Accuracy: 89.06%
# Iteration 706/10000, Loss: 0.5240, Accuracy: 89.06%
# Iteration 707/10000, Loss: 0.5238, Accuracy: 89.06%
# Iteration 708/10000, Loss: 0.5235, Accuracy: 89.11%
# Iteration 709/10000, Loss: 0.5233, Accuracy: 89.16%
# Iteration 710/10000, Loss: 0.5231, Accuracy: 89.21%
# Iteration 711/10000, Loss: 0.5228, Accuracy: 89.21%
# Iteration 712/10000, Loss: 0.5226, Accuracy: 89.21%
# Iteration 713/10000, Loss: 0.5224, Accuracy: 89.21%
# Iteration 714/10000, Loss: 0.5221, Accuracy: 89.21%
# Iteration 715/10000, Loss: 0.5219, Accuracy: 89.21%
# Iteration 716/10000, Loss: 0.5217, Accuracy: 89.26%
# Iteration 717/10000, Loss: 0.5214, Accuracy: 89.26%
# Iteration 718/10000, Loss: 0.5212, Accuracy: 89.26%
# Iteration 719/10000, Loss: 0.5210, Accuracy: 89.26%
# Iteration 720/10000, Loss: 0.5207, Accuracy: 89.26%
# Iteration 721/10000, Loss: 0.5205, Accuracy: 89.26%
# Iteration 722/10000, Loss: 0.5203, Accuracy: 89.36%
# Iteration 723/10000, Loss: 0.5200, Accuracy: 89.36%
# Iteration 724/10000, Loss: 0.5198, Accuracy: 89.36%
# Iteration 725/10000, Loss: 0.5196, Accuracy: 89.36%
# Iteration 726/10000, Loss: 0.5194, Accuracy: 89.40%
# Iteration 727/10000, Loss: 0.5191, Accuracy: 89.40%
# Iteration 728/10000, Loss: 0.5189, Accuracy: 89.50%
# Iteration 729/10000, Loss: 0.5187, Accuracy: 89.50%
# Iteration 730/10000, Loss: 0.5184, Accuracy: 89.50%
# Iteration 731/10000, Loss: 0.5182, Accuracy: 89.50%
# Iteration 732/10000, Loss: 0.5180, Accuracy: 89.50%
# Iteration 733/10000, Loss: 0.5177, Accuracy: 89.60%
# Iteration 734/10000, Loss: 0.5175, Accuracy: 89.60%
# Iteration 735/10000, Loss: 0.5173, Accuracy: 89.65%
# Iteration 736/10000, Loss: 0.5171, Accuracy: 89.65%
# Iteration 737/10000, Loss: 0.5168, Accuracy: 89.65%
# Iteration 738/10000, Loss: 0.5166, Accuracy: 89.70%
# Iteration 739/10000, Loss: 0.5164, Accuracy: 89.70%
# Iteration 740/10000, Loss: 0.5161, Accuracy: 89.75%
# Iteration 741/10000, Loss: 0.5159, Accuracy: 89.79%
# Iteration 742/10000, Loss: 0.5157, Accuracy: 89.79%
# Iteration 743/10000, Loss: 0.5155, Accuracy: 89.79%
# Iteration 744/10000, Loss: 0.5152, Accuracy: 89.79%
# Iteration 745/10000, Loss: 0.5150, Accuracy: 89.84%
# Iteration 746/10000, Loss: 0.5148, Accuracy: 89.89%
# Iteration 747/10000, Loss: 0.5146, Accuracy: 89.89%
# Iteration 748/10000, Loss: 0.5143, Accuracy: 89.89%
# Iteration 749/10000, Loss: 0.5141, Accuracy: 89.89%
# Iteration 750/10000, Loss: 0.5139, Accuracy: 89.89%
# Iteration 751/10000, Loss: 0.5137, Accuracy: 89.89%
# Iteration 752/10000, Loss: 0.5134, Accuracy: 89.89%
# Iteration 753/10000, Loss: 0.5132, Accuracy: 89.94%
# Iteration 754/10000, Loss: 0.5130, Accuracy: 89.94%
# Iteration 755/10000, Loss: 0.5128, Accuracy: 89.99%
# Iteration 756/10000, Loss: 0.5125, Accuracy: 89.99%
# Iteration 757/10000, Loss: 0.5123, Accuracy: 90.04%
# Iteration 758/10000, Loss: 0.5121, Accuracy: 90.04%
# Iteration 759/10000, Loss: 0.5119, Accuracy: 90.04%
# Iteration 760/10000, Loss: 0.5116, Accuracy: 90.09%
# Iteration 761/10000, Loss: 0.5114, Accuracy: 90.09%
# Iteration 762/10000, Loss: 0.5112, Accuracy: 90.09%
# Iteration 763/10000, Loss: 0.5110, Accuracy: 90.09%
# Iteration 764/10000, Loss: 0.5108, Accuracy: 90.14%
# Iteration 765/10000, Loss: 0.5105, Accuracy: 90.14%
# Iteration 766/10000, Loss: 0.5103, Accuracy: 90.14%
# Iteration 767/10000, Loss: 0.5101, Accuracy: 90.19%
# Iteration 768/10000, Loss: 0.5099, Accuracy: 90.23%
# Iteration 769/10000, Loss: 0.5096, Accuracy: 90.23%
# Iteration 770/10000, Loss: 0.5094, Accuracy: 90.23%
# Iteration 771/10000, Loss: 0.5092, Accuracy: 90.23%
# Iteration 772/10000, Loss: 0.5090, Accuracy: 90.23%
# Iteration 773/10000, Loss: 0.5088, Accuracy: 90.23%
# Iteration 774/10000, Loss: 0.5085, Accuracy: 90.23%
# Iteration 775/10000, Loss: 0.5083, Accuracy: 90.23%
# Iteration 776/10000, Loss: 0.5081, Accuracy: 90.33%
# Iteration 777/10000, Loss: 0.5079, Accuracy: 90.38%
# Iteration 778/10000, Loss: 0.5077, Accuracy: 90.38%
# Iteration 779/10000, Loss: 0.5074, Accuracy: 90.38%
# Iteration 780/10000, Loss: 0.5072, Accuracy: 90.43%
# Iteration 781/10000, Loss: 0.5070, Accuracy: 90.43%
# Iteration 782/10000, Loss: 0.5068, Accuracy: 90.43%
# Iteration 783/10000, Loss: 0.5066, Accuracy: 90.43%
# Iteration 784/10000, Loss: 0.5064, Accuracy: 90.43%
# Iteration 785/10000, Loss: 0.5061, Accuracy: 90.43%
# Iteration 786/10000, Loss: 0.5059, Accuracy: 90.43%
# Iteration 787/10000, Loss: 0.5057, Accuracy: 90.43%
# Iteration 788/10000, Loss: 0.5055, Accuracy: 90.48%
# Iteration 789/10000, Loss: 0.5053, Accuracy: 90.48%
# Iteration 790/10000, Loss: 0.5050, Accuracy: 90.53%
# Iteration 791/10000, Loss: 0.5048, Accuracy: 90.53%
# Iteration 792/10000, Loss: 0.5046, Accuracy: 90.53%
# Iteration 793/10000, Loss: 0.5044, Accuracy: 90.62%
# Iteration 794/10000, Loss: 0.5042, Accuracy: 90.72%
# Iteration 795/10000, Loss: 0.5040, Accuracy: 90.72%
# Iteration 796/10000, Loss: 0.5038, Accuracy: 90.72%
# Iteration 797/10000, Loss: 0.5035, Accuracy: 90.77%
# Iteration 798/10000, Loss: 0.5033, Accuracy: 90.77%
# Iteration 799/10000, Loss: 0.5031, Accuracy: 90.77%
# Iteration 800/10000, Loss: 0.5029, Accuracy: 90.82%
# Iteration 801/10000, Loss: 0.5027, Accuracy: 90.82%
# Iteration 802/10000, Loss: 0.5025, Accuracy: 90.87%
# Iteration 803/10000, Loss: 0.5022, Accuracy: 90.87%
# Iteration 804/10000, Loss: 0.5020, Accuracy: 90.87%
# Iteration 805/10000, Loss: 0.5018, Accuracy: 90.87%
# Iteration 806/10000, Loss: 0.5016, Accuracy: 90.87%
# Iteration 807/10000, Loss: 0.5014, Accuracy: 90.87%
# Iteration 808/10000, Loss: 0.5012, Accuracy: 90.87%
# Iteration 809/10000, Loss: 0.5010, Accuracy: 90.87%
# Iteration 810/10000, Loss: 0.5008, Accuracy: 90.92%
# Iteration 811/10000, Loss: 0.5005, Accuracy: 90.97%
# Iteration 812/10000, Loss: 0.5003, Accuracy: 90.97%
# Iteration 813/10000, Loss: 0.5001, Accuracy: 90.97%
# Iteration 814/10000, Loss: 0.4999, Accuracy: 90.97%
# Iteration 815/10000, Loss: 0.4997, Accuracy: 91.02%
# Iteration 816/10000, Loss: 0.4995, Accuracy: 91.06%
# Iteration 817/10000, Loss: 0.4993, Accuracy: 91.06%
# Iteration 818/10000, Loss: 0.4991, Accuracy: 91.11%
# Iteration 819/10000, Loss: 0.4989, Accuracy: 91.11%
# Iteration 820/10000, Loss: 0.4986, Accuracy: 91.11%
# Iteration 821/10000, Loss: 0.4984, Accuracy: 91.11%
# Iteration 822/10000, Loss: 0.4982, Accuracy: 91.21%
# Iteration 823/10000, Loss: 0.4980, Accuracy: 91.21%
# Iteration 824/10000, Loss: 0.4978, Accuracy: 91.21%
# Iteration 825/10000, Loss: 0.4976, Accuracy: 91.26%
# Iteration 826/10000, Loss: 0.4974, Accuracy: 91.26%
# Iteration 827/10000, Loss: 0.4972, Accuracy: 91.36%
# Iteration 828/10000, Loss: 0.4970, Accuracy: 91.46%
# Iteration 829/10000, Loss: 0.4968, Accuracy: 91.46%
# Iteration 830/10000, Loss: 0.4965, Accuracy: 91.46%
# Iteration 831/10000, Loss: 0.4963, Accuracy: 91.46%
# Iteration 832/10000, Loss: 0.4961, Accuracy: 91.46%
# Iteration 833/10000, Loss: 0.4959, Accuracy: 91.50%
# Iteration 834/10000, Loss: 0.4957, Accuracy: 91.50%
# Iteration 835/10000, Loss: 0.4955, Accuracy: 91.50%
# Iteration 836/10000, Loss: 0.4953, Accuracy: 91.50%
# Iteration 837/10000, Loss: 0.4951, Accuracy: 91.60%
# Iteration 838/10000, Loss: 0.4949, Accuracy: 91.65%
# Iteration 839/10000, Loss: 0.4947, Accuracy: 91.65%
# Iteration 840/10000, Loss: 0.4945, Accuracy: 91.65%
# Iteration 841/10000, Loss: 0.4943, Accuracy: 91.70%
# Iteration 842/10000, Loss: 0.4941, Accuracy: 91.85%
# Iteration 843/10000, Loss: 0.4939, Accuracy: 91.85%
# Iteration 844/10000, Loss: 0.4936, Accuracy: 91.85%
# Iteration 845/10000, Loss: 0.4934, Accuracy: 91.85%
# Iteration 846/10000, Loss: 0.4932, Accuracy: 91.85%
# Iteration 847/10000, Loss: 0.4930, Accuracy: 91.89%
# Iteration 848/10000, Loss: 0.4928, Accuracy: 91.89%
# Iteration 849/10000, Loss: 0.4926, Accuracy: 91.89%
# Iteration 850/10000, Loss: 0.4924, Accuracy: 91.89%
# Iteration 851/10000, Loss: 0.4922, Accuracy: 91.89%
# Iteration 852/10000, Loss: 0.4920, Accuracy: 91.89%
# Iteration 853/10000, Loss: 0.4918, Accuracy: 91.94%
# Iteration 854/10000, Loss: 0.4916, Accuracy: 91.94%
# Iteration 855/10000, Loss: 0.4914, Accuracy: 91.94%
# Iteration 856/10000, Loss: 0.4912, Accuracy: 91.94%
# Iteration 857/10000, Loss: 0.4910, Accuracy: 91.94%
# Iteration 858/10000, Loss: 0.4908, Accuracy: 91.94%
# Iteration 859/10000, Loss: 0.4906, Accuracy: 91.94%
# Iteration 860/10000, Loss: 0.4904, Accuracy: 91.94%
# Iteration 861/10000, Loss: 0.4902, Accuracy: 91.94%
# Iteration 862/10000, Loss: 0.4900, Accuracy: 91.99%
# Iteration 863/10000, Loss: 0.4898, Accuracy: 91.99%
# Iteration 864/10000, Loss: 0.4896, Accuracy: 91.99%
# Iteration 865/10000, Loss: 0.4894, Accuracy: 91.99%
# Iteration 866/10000, Loss: 0.4892, Accuracy: 91.99%
# Iteration 867/10000, Loss: 0.4890, Accuracy: 91.99%
# Iteration 868/10000, Loss: 0.4888, Accuracy: 91.99%
# Iteration 869/10000, Loss: 0.4886, Accuracy: 91.99%
# Iteration 870/10000, Loss: 0.4884, Accuracy: 91.99%
# Iteration 871/10000, Loss: 0.4882, Accuracy: 92.04%
# Iteration 872/10000, Loss: 0.4880, Accuracy: 92.04%
# Iteration 873/10000, Loss: 0.4878, Accuracy: 92.04%
# Iteration 874/10000, Loss: 0.4876, Accuracy: 92.09%
# Iteration 875/10000, Loss: 0.4874, Accuracy: 92.14%
# Iteration 876/10000, Loss: 0.4872, Accuracy: 92.19%
# Iteration 877/10000, Loss: 0.4870, Accuracy: 92.19%
# Iteration 878/10000, Loss: 0.4868, Accuracy: 92.19%
# Iteration 879/10000, Loss: 0.4866, Accuracy: 92.19%
# Iteration 880/10000, Loss: 0.4864, Accuracy: 92.19%
# Iteration 881/10000, Loss: 0.4862, Accuracy: 92.19%
# Iteration 882/10000, Loss: 0.4860, Accuracy: 92.19%
# Iteration 883/10000, Loss: 0.4858, Accuracy: 92.19%
# Iteration 884/10000, Loss: 0.4856, Accuracy: 92.19%
# Iteration 885/10000, Loss: 0.4854, Accuracy: 92.19%
# Iteration 886/10000, Loss: 0.4852, Accuracy: 92.19%
# Iteration 887/10000, Loss: 0.4850, Accuracy: 92.19%
# Iteration 888/10000, Loss: 0.4848, Accuracy: 92.19%
# Iteration 889/10000, Loss: 0.4846, Accuracy: 92.19%
# Iteration 890/10000, Loss: 0.4844, Accuracy: 92.19%
# Iteration 891/10000, Loss: 0.4842, Accuracy: 92.19%
# Iteration 892/10000, Loss: 0.4840, Accuracy: 92.24%
# Iteration 893/10000, Loss: 0.4838, Accuracy: 92.24%
# Iteration 894/10000, Loss: 0.4836, Accuracy: 92.24%
# Iteration 895/10000, Loss: 0.4834, Accuracy: 92.24%
# Iteration 896/10000, Loss: 0.4832, Accuracy: 92.29%
# Iteration 897/10000, Loss: 0.4830, Accuracy: 92.29%
# Iteration 898/10000, Loss: 0.4828, Accuracy: 92.29%
# Iteration 899/10000, Loss: 0.4826, Accuracy: 92.29%
# Iteration 900/10000, Loss: 0.4824, Accuracy: 92.33%
# Iteration 901/10000, Loss: 0.4822, Accuracy: 92.38%
# Iteration 902/10000, Loss: 0.4820, Accuracy: 92.43%
# Iteration 903/10000, Loss: 0.4818, Accuracy: 92.43%
# Iteration 904/10000, Loss: 0.4816, Accuracy: 92.43%
# Iteration 905/10000, Loss: 0.4815, Accuracy: 92.43%
# Iteration 906/10000, Loss: 0.4813, Accuracy: 92.43%
# Iteration 907/10000, Loss: 0.4811, Accuracy: 92.43%
# Iteration 908/10000, Loss: 0.4809, Accuracy: 92.48%
# Iteration 909/10000, Loss: 0.4807, Accuracy: 92.48%
# Iteration 910/10000, Loss: 0.4805, Accuracy: 92.48%
# Iteration 911/10000, Loss: 0.4803, Accuracy: 92.48%
# Iteration 912/10000, Loss: 0.4801, Accuracy: 92.48%
# Iteration 913/10000, Loss: 0.4799, Accuracy: 92.48%
# Iteration 914/10000, Loss: 0.4797, Accuracy: 92.48%
# Iteration 915/10000, Loss: 0.4795, Accuracy: 92.53%
# Iteration 916/10000, Loss: 0.4793, Accuracy: 92.58%
# Iteration 917/10000, Loss: 0.4791, Accuracy: 92.58%
# Iteration 918/10000, Loss: 0.4789, Accuracy: 92.58%
# Iteration 919/10000, Loss: 0.4788, Accuracy: 92.63%
# Iteration 920/10000, Loss: 0.4786, Accuracy: 92.68%
# Iteration 921/10000, Loss: 0.4784, Accuracy: 92.68%
# Iteration 922/10000, Loss: 0.4782, Accuracy: 92.72%
# Iteration 923/10000, Loss: 0.4780, Accuracy: 92.72%
# Iteration 924/10000, Loss: 0.4778, Accuracy: 92.72%
# Iteration 925/10000, Loss: 0.4776, Accuracy: 92.72%
# ...
# Iteration 9700/10000, Loss: 0.1659, Accuracy: 96.24%
# Iteration 9701/10000, Loss: 0.1659, Accuracy: 96.24%
# Iteration 9702/10000, Loss: 0.1659, Accuracy: 96.24%
# Iteration 9703/10000, Loss: 0.1659, Accuracy: 96.24%
# Iteration 9704/10000, Loss: 0.1659, Accuracy: 96.24%
# Iteration 9705/10000, Loss: 0.1659, Accuracy: 96.24%
# Iteration 9706/10000, Loss: 0.1659, Accuracy: 96.24%
# Iteration 9707/10000, Loss: 0.1659, Accuracy: 96.24%
# Iteration 9708/10000, Loss: 0.1659, Accuracy: 96.24%
# Iteration 9709/10000, Loss: 0.1659, Accuracy: 96.24%
# Iteration 9710/10000, Loss: 0.1659, Accuracy: 96.24%
# Iteration 9711/10000, Loss: 0.1659, Accuracy: 96.24%
# Iteration 9712/10000, Loss: 0.1659, Accuracy: 96.24%
# Iteration 9713/10000, Loss: 0.1658, Accuracy: 96.24%
# Iteration 9714/10000, Loss: 0.1658, Accuracy: 96.24%
# Iteration 9715/10000, Loss: 0.1658, Accuracy: 96.24%
# Iteration 9716/10000, Loss: 0.1658, Accuracy: 96.24%
# Iteration 9717/10000, Loss: 0.1658, Accuracy: 96.24%
# Iteration 9718/10000, Loss: 0.1658, Accuracy: 96.24%
# Iteration 9719/10000, Loss: 0.1658, Accuracy: 96.24%
# Iteration 9720/10000, Loss: 0.1658, Accuracy: 96.24%
# Iteration 9721/10000, Loss: 0.1658, Accuracy: 96.24%
# Iteration 9722/10000, Loss: 0.1658, Accuracy: 96.24%
# Iteration 9723/10000, Loss: 0.1658, Accuracy: 96.24%
# Iteration 9724/10000, Loss: 0.1658, Accuracy: 96.24%
# Iteration 9725/10000, Loss: 0.1658, Accuracy: 96.24%
# Iteration 9726/10000, Loss: 0.1658, Accuracy: 96.24%
# Iteration 9727/10000, Loss: 0.1658, Accuracy: 96.24%
# Iteration 9728/10000, Loss: 0.1657, Accuracy: 96.24%
# Iteration 9729/10000, Loss: 0.1657, Accuracy: 96.24%
# Iteration 9730/10000, Loss: 0.1657, Accuracy: 96.24%
# Iteration 9731/10000, Loss: 0.1657, Accuracy: 96.24%
# Iteration 9732/10000, Loss: 0.1657, Accuracy: 96.24%
# Iteration 9733/10000, Loss: 0.1657, Accuracy: 96.24%
# Iteration 9734/10000, Loss: 0.1657, Accuracy: 96.24%
# Iteration 9735/10000, Loss: 0.1657, Accuracy: 96.24%
# Iteration 9736/10000, Loss: 0.1657, Accuracy: 96.24%
# Iteration 9737/10000, Loss: 0.1657, Accuracy: 96.24%
# Iteration 9738/10000, Loss: 0.1657, Accuracy: 96.24%
# Iteration 9739/10000, Loss: 0.1657, Accuracy: 96.24%
# Iteration 9740/10000, Loss: 0.1657, Accuracy: 96.24%
# Iteration 9741/10000, Loss: 0.1657, Accuracy: 96.24%
# Iteration 9742/10000, Loss: 0.1657, Accuracy: 96.24%
# Iteration 9743/10000, Loss: 0.1657, Accuracy: 96.24%
# Iteration 9744/10000, Loss: 0.1656, Accuracy: 96.24%
# Iteration 9745/10000, Loss: 0.1656, Accuracy: 96.24%
# Iteration 9746/10000, Loss: 0.1656, Accuracy: 96.24%
# Iteration 9747/10000, Loss: 0.1656, Accuracy: 96.24%
# Iteration 9748/10000, Loss: 0.1656, Accuracy: 96.24%
# Iteration 9749/10000, Loss: 0.1656, Accuracy: 96.24%
# Iteration 9750/10000, Loss: 0.1656, Accuracy: 96.24%
# Iteration 9751/10000, Loss: 0.1656, Accuracy: 96.24%
# Iteration 9752/10000, Loss: 0.1656, Accuracy: 96.24%
# Iteration 9753/10000, Loss: 0.1656, Accuracy: 96.24%
# Iteration 9754/10000, Loss: 0.1656, Accuracy: 96.24%
# Iteration 9755/10000, Loss: 0.1656, Accuracy: 96.24%
# Iteration 9756/10000, Loss: 0.1656, Accuracy: 96.24%
# Iteration 9757/10000, Loss: 0.1656, Accuracy: 96.24%
# Iteration 9758/10000, Loss: 0.1656, Accuracy: 96.24%
# Iteration 9759/10000, Loss: 0.1655, Accuracy: 96.24%
# Iteration 9760/10000, Loss: 0.1655, Accuracy: 96.24%
# Iteration 9761/10000, Loss: 0.1655, Accuracy: 96.24%
# Iteration 9762/10000, Loss: 0.1655, Accuracy: 96.24%
# Iteration 9763/10000, Loss: 0.1655, Accuracy: 96.24%
# Iteration 9764/10000, Loss: 0.1655, Accuracy: 96.24%
# Iteration 9765/10000, Loss: 0.1655, Accuracy: 96.24%
# Iteration 9766/10000, Loss: 0.1655, Accuracy: 96.24%
# Iteration 9767/10000, Loss: 0.1655, Accuracy: 96.24%
# Iteration 9768/10000, Loss: 0.1655, Accuracy: 96.24%
# Iteration 9769/10000, Loss: 0.1655, Accuracy: 96.24%
# Iteration 9770/10000, Loss: 0.1655, Accuracy: 96.24%
# Iteration 9771/10000, Loss: 0.1655, Accuracy: 96.24%
# Iteration 9772/10000, Loss: 0.1655, Accuracy: 96.24%
# Iteration 9773/10000, Loss: 0.1655, Accuracy: 96.24%
# Iteration 9774/10000, Loss: 0.1655, Accuracy: 96.24%
# Iteration 9775/10000, Loss: 0.1654, Accuracy: 96.24%
# Iteration 9776/10000, Loss: 0.1654, Accuracy: 96.24%
# Iteration 9777/10000, Loss: 0.1654, Accuracy: 96.24%
# Iteration 9778/10000, Loss: 0.1654, Accuracy: 96.24%
# Iteration 9779/10000, Loss: 0.1654, Accuracy: 96.24%
# Iteration 9780/10000, Loss: 0.1654, Accuracy: 96.24%
# Iteration 9781/10000, Loss: 0.1654, Accuracy: 96.24%
# Iteration 9782/10000, Loss: 0.1654, Accuracy: 96.24%
# Iteration 9783/10000, Loss: 0.1654, Accuracy: 96.24%
# Iteration 9784/10000, Loss: 0.1654, Accuracy: 96.24%
# Iteration 9785/10000, Loss: 0.1654, Accuracy: 96.24%
# Iteration 9786/10000, Loss: 0.1654, Accuracy: 96.24%
# Iteration 9787/10000, Loss: 0.1654, Accuracy: 96.24%
# Iteration 9788/10000, Loss: 0.1654, Accuracy: 96.24%
# Iteration 9789/10000, Loss: 0.1654, Accuracy: 96.24%
# Iteration 9790/10000, Loss: 0.1653, Accuracy: 96.24%
# Iteration 9791/10000, Loss: 0.1653, Accuracy: 96.24%
# Iteration 9792/10000, Loss: 0.1653, Accuracy: 96.24%
# Iteration 9793/10000, Loss: 0.1653, Accuracy: 96.24%
# Iteration 9794/10000, Loss: 0.1653, Accuracy: 96.24%
# Iteration 9795/10000, Loss: 0.1653, Accuracy: 96.24%
# Iteration 9796/10000, Loss: 0.1653, Accuracy: 96.24%
# Iteration 9797/10000, Loss: 0.1653, Accuracy: 96.24%
# Iteration 9798/10000, Loss: 0.1653, Accuracy: 96.24%
# Iteration 9799/10000, Loss: 0.1653, Accuracy: 96.24%
# Iteration 9800/10000, Loss: 0.1653, Accuracy: 96.24%
# Iteration 9801/10000, Loss: 0.1653, Accuracy: 96.24%
# Iteration 9802/10000, Loss: 0.1653, Accuracy: 96.24%
# Iteration 9803/10000, Loss: 0.1653, Accuracy: 96.24%
# Iteration 9804/10000, Loss: 0.1653, Accuracy: 96.24%
# Iteration 9805/10000, Loss: 0.1653, Accuracy: 96.24%
# Iteration 9806/10000, Loss: 0.1652, Accuracy: 96.24%
# Iteration 9807/10000, Loss: 0.1652, Accuracy: 96.24%
# Iteration 9808/10000, Loss: 0.1652, Accuracy: 96.24%
# Iteration 9809/10000, Loss: 0.1652, Accuracy: 96.24%
# Iteration 9810/10000, Loss: 0.1652, Accuracy: 96.24%
# Iteration 9811/10000, Loss: 0.1652, Accuracy: 96.24%
# Iteration 9812/10000, Loss: 0.1652, Accuracy: 96.24%
# Iteration 9813/10000, Loss: 0.1652, Accuracy: 96.24%
# Iteration 9814/10000, Loss: 0.1652, Accuracy: 96.24%
# Iteration 9815/10000, Loss: 0.1652, Accuracy: 96.24%
# Iteration 9816/10000, Loss: 0.1652, Accuracy: 96.24%
# Iteration 9817/10000, Loss: 0.1652, Accuracy: 96.24%
# Iteration 9818/10000, Loss: 0.1652, Accuracy: 96.24%
# Iteration 9819/10000, Loss: 0.1652, Accuracy: 96.24%
# Iteration 9820/10000, Loss: 0.1652, Accuracy: 96.24%
# Iteration 9821/10000, Loss: 0.1651, Accuracy: 96.24%
# Iteration 9822/10000, Loss: 0.1651, Accuracy: 96.24%
# Iteration 9823/10000, Loss: 0.1651, Accuracy: 96.24%
# Iteration 9824/10000, Loss: 0.1651, Accuracy: 96.24%
# Iteration 9825/10000, Loss: 0.1651, Accuracy: 96.24%
# Iteration 9826/10000, Loss: 0.1651, Accuracy: 96.24%
# Iteration 9827/10000, Loss: 0.1651, Accuracy: 96.24%
# Iteration 9828/10000, Loss: 0.1651, Accuracy: 96.24%
# Iteration 9829/10000, Loss: 0.1651, Accuracy: 96.24%
# Iteration 9830/10000, Loss: 0.1651, Accuracy: 96.24%
# Iteration 9831/10000, Loss: 0.1651, Accuracy: 96.24%
# Iteration 9832/10000, Loss: 0.1651, Accuracy: 96.24%
# Iteration 9833/10000, Loss: 0.1651, Accuracy: 96.24%
# Iteration 9834/10000, Loss: 0.1651, Accuracy: 96.24%
# Iteration 9835/10000, Loss: 0.1651, Accuracy: 96.24%
# Iteration 9836/10000, Loss: 0.1651, Accuracy: 96.24%
# Iteration 9837/10000, Loss: 0.1650, Accuracy: 96.24%
# Iteration 9838/10000, Loss: 0.1650, Accuracy: 96.24%
# Iteration 9839/10000, Loss: 0.1650, Accuracy: 96.24%
# Iteration 9840/10000, Loss: 0.1650, Accuracy: 96.24%
# Iteration 9841/10000, Loss: 0.1650, Accuracy: 96.24%
# Iteration 9842/10000, Loss: 0.1650, Accuracy: 96.24%
# Iteration 9843/10000, Loss: 0.1650, Accuracy: 96.24%
# Iteration 9844/10000, Loss: 0.1650, Accuracy: 96.24%
# Iteration 9845/10000, Loss: 0.1650, Accuracy: 96.24%
# Iteration 9846/10000, Loss: 0.1650, Accuracy: 96.24%
# Iteration 9847/10000, Loss: 0.1650, Accuracy: 96.24%
# Iteration 9848/10000, Loss: 0.1650, Accuracy: 96.24%
# Iteration 9849/10000, Loss: 0.1650, Accuracy: 96.24%
# Iteration 9850/10000, Loss: 0.1650, Accuracy: 96.24%
# Iteration 9851/10000, Loss: 0.1650, Accuracy: 96.24%
# Iteration 9852/10000, Loss: 0.1650, Accuracy: 96.24%
# Iteration 9853/10000, Loss: 0.1649, Accuracy: 96.24%
# Iteration 9854/10000, Loss: 0.1649, Accuracy: 96.24%
# Iteration 9855/10000, Loss: 0.1649, Accuracy: 96.24%
# Iteration 9856/10000, Loss: 0.1649, Accuracy: 96.24%
# Iteration 9857/10000, Loss: 0.1649, Accuracy: 96.24%
# Iteration 9858/10000, Loss: 0.1649, Accuracy: 96.24%
# Iteration 9859/10000, Loss: 0.1649, Accuracy: 96.24%
# Iteration 9860/10000, Loss: 0.1649, Accuracy: 96.24%
# Iteration 9861/10000, Loss: 0.1649, Accuracy: 96.24%
# Iteration 9862/10000, Loss: 0.1649, Accuracy: 96.24%
# Iteration 9863/10000, Loss: 0.1649, Accuracy: 96.24%
# Iteration 9864/10000, Loss: 0.1649, Accuracy: 96.24%
# Iteration 9865/10000, Loss: 0.1649, Accuracy: 96.24%
# Iteration 9866/10000, Loss: 0.1649, Accuracy: 96.24%
# Iteration 9867/10000, Loss: 0.1649, Accuracy: 96.24%
# Iteration 9868/10000, Loss: 0.1648, Accuracy: 96.24%
# Iteration 9869/10000, Loss: 0.1648, Accuracy: 96.24%
# Iteration 9870/10000, Loss: 0.1648, Accuracy: 96.24%
# Iteration 9871/10000, Loss: 0.1648, Accuracy: 96.24%
# Iteration 9872/10000, Loss: 0.1648, Accuracy: 96.24%
# Iteration 9873/10000, Loss: 0.1648, Accuracy: 96.24%
# Iteration 9874/10000, Loss: 0.1648, Accuracy: 96.24%
# Iteration 9875/10000, Loss: 0.1648, Accuracy: 96.24%
# Iteration 9876/10000, Loss: 0.1648, Accuracy: 96.24%
# Iteration 9877/10000, Loss: 0.1648, Accuracy: 96.24%
# Iteration 9878/10000, Loss: 0.1648, Accuracy: 96.24%
# Iteration 9879/10000, Loss: 0.1648, Accuracy: 96.24%
# Iteration 9880/10000, Loss: 0.1648, Accuracy: 96.24%
# Iteration 9881/10000, Loss: 0.1648, Accuracy: 96.24%
# Iteration 9882/10000, Loss: 0.1648, Accuracy: 96.24%
# Iteration 9883/10000, Loss: 0.1648, Accuracy: 96.24%
# Iteration 9884/10000, Loss: 0.1647, Accuracy: 96.24%
# Iteration 9885/10000, Loss: 0.1647, Accuracy: 96.24%
# Iteration 9886/10000, Loss: 0.1647, Accuracy: 96.24%
# Iteration 9887/10000, Loss: 0.1647, Accuracy: 96.24%
# Iteration 9888/10000, Loss: 0.1647, Accuracy: 96.24%
# Iteration 9889/10000, Loss: 0.1647, Accuracy: 96.24%
# Iteration 9890/10000, Loss: 0.1647, Accuracy: 96.24%
# Iteration 9891/10000, Loss: 0.1647, Accuracy: 96.24%
# Iteration 9892/10000, Loss: 0.1647, Accuracy: 96.24%
# Iteration 9893/10000, Loss: 0.1647, Accuracy: 96.24%
# Iteration 9894/10000, Loss: 0.1647, Accuracy: 96.24%
# Iteration 9895/10000, Loss: 0.1647, Accuracy: 96.24%
# Iteration 9896/10000, Loss: 0.1647, Accuracy: 96.24%
# Iteration 9897/10000, Loss: 0.1647, Accuracy: 96.24%
# Iteration 9898/10000, Loss: 0.1647, Accuracy: 96.24%
# Iteration 9899/10000, Loss: 0.1647, Accuracy: 96.24%
# Iteration 9900/10000, Loss: 0.1646, Accuracy: 96.24%
# Iteration 9901/10000, Loss: 0.1646, Accuracy: 96.24%
# Iteration 9902/10000, Loss: 0.1646, Accuracy: 96.24%
# Iteration 9903/10000, Loss: 0.1646, Accuracy: 96.24%
# Iteration 9904/10000, Loss: 0.1646, Accuracy: 96.24%
# Iteration 9905/10000, Loss: 0.1646, Accuracy: 96.24%
# Iteration 9906/10000, Loss: 0.1646, Accuracy: 96.24%
# Iteration 9907/10000, Loss: 0.1646, Accuracy: 96.24%
# Iteration 9908/10000, Loss: 0.1646, Accuracy: 96.24%
# Iteration 9909/10000, Loss: 0.1646, Accuracy: 96.24%
# Iteration 9910/10000, Loss: 0.1646, Accuracy: 96.24%
# Iteration 9911/10000, Loss: 0.1646, Accuracy: 96.24%
# Iteration 9912/10000, Loss: 0.1646, Accuracy: 96.24%
# Iteration 9913/10000, Loss: 0.1646, Accuracy: 96.24%
# Iteration 9914/10000, Loss: 0.1646, Accuracy: 96.24%
# Iteration 9915/10000, Loss: 0.1646, Accuracy: 96.24%
# Iteration 9916/10000, Loss: 0.1645, Accuracy: 96.24%
# Iteration 9917/10000, Loss: 0.1645, Accuracy: 96.24%
# Iteration 9918/10000, Loss: 0.1645, Accuracy: 96.24%
# Iteration 9919/10000, Loss: 0.1645, Accuracy: 96.24%
# Iteration 9920/10000, Loss: 0.1645, Accuracy: 96.24%
# Iteration 9921/10000, Loss: 0.1645, Accuracy: 96.24%
# Iteration 9922/10000, Loss: 0.1645, Accuracy: 96.24%
# Iteration 9923/10000, Loss: 0.1645, Accuracy: 96.24%
# Iteration 9924/10000, Loss: 0.1645, Accuracy: 96.24%
# Iteration 9925/10000, Loss: 0.1645, Accuracy: 96.24%
# Iteration 9926/10000, Loss: 0.1645, Accuracy: 96.24%
# Iteration 9927/10000, Loss: 0.1645, Accuracy: 96.24%
# Iteration 9928/10000, Loss: 0.1645, Accuracy: 96.24%
# Iteration 9929/10000, Loss: 0.1645, Accuracy: 96.24%
# Iteration 9930/10000, Loss: 0.1645, Accuracy: 96.24%
# Iteration 9931/10000, Loss: 0.1645, Accuracy: 96.24%
# Iteration 9932/10000, Loss: 0.1644, Accuracy: 96.24%
# Iteration 9933/10000, Loss: 0.1644, Accuracy: 96.24%
# Iteration 9934/10000, Loss: 0.1644, Accuracy: 96.24%
# Iteration 9935/10000, Loss: 0.1644, Accuracy: 96.24%
# Iteration 9936/10000, Loss: 0.1644, Accuracy: 96.24%
# Iteration 9937/10000, Loss: 0.1644, Accuracy: 96.24%
# Iteration 9938/10000, Loss: 0.1644, Accuracy: 96.24%
# Iteration 9939/10000, Loss: 0.1644, Accuracy: 96.24%
# Iteration 9940/10000, Loss: 0.1644, Accuracy: 96.24%
# Iteration 9941/10000, Loss: 0.1644, Accuracy: 96.24%
# Iteration 9942/10000, Loss: 0.1644, Accuracy: 96.24%
# Iteration 9943/10000, Loss: 0.1644, Accuracy: 96.24%
# Iteration 9944/10000, Loss: 0.1644, Accuracy: 96.24%
# Iteration 9945/10000, Loss: 0.1644, Accuracy: 96.24%
# Iteration 9946/10000, Loss: 0.1644, Accuracy: 96.24%
# Iteration 9947/10000, Loss: 0.1644, Accuracy: 96.24%
# Iteration 9948/10000, Loss: 0.1643, Accuracy: 96.24%
# Iteration 9949/10000, Loss: 0.1643, Accuracy: 96.24%
# Iteration 9950/10000, Loss: 0.1643, Accuracy: 96.24%
# Iteration 9951/10000, Loss: 0.1643, Accuracy: 96.24%
# Iteration 9952/10000, Loss: 0.1643, Accuracy: 96.24%
# Iteration 9953/10000, Loss: 0.1643, Accuracy: 96.24%
# Iteration 9954/10000, Loss: 0.1643, Accuracy: 96.24%
# Iteration 9955/10000, Loss: 0.1643, Accuracy: 96.24%
# Iteration 9956/10000, Loss: 0.1643, Accuracy: 96.24%
# Iteration 9957/10000, Loss: 0.1643, Accuracy: 96.24%
# Iteration 9958/10000, Loss: 0.1643, Accuracy: 96.24%
# Iteration 9959/10000, Loss: 0.1643, Accuracy: 96.24%
# Iteration 9960/10000, Loss: 0.1643, Accuracy: 96.24%
# Iteration 9961/10000, Loss: 0.1643, Accuracy: 96.24%
# Iteration 9962/10000, Loss: 0.1643, Accuracy: 96.24%
# Iteration 9963/10000, Loss: 0.1643, Accuracy: 96.24%
# Iteration 9964/10000, Loss: 0.1642, Accuracy: 96.24%
# Iteration 9965/10000, Loss: 0.1642, Accuracy: 96.24%
# Iteration 9966/10000, Loss: 0.1642, Accuracy: 96.24%
# Iteration 9967/10000, Loss: 0.1642, Accuracy: 96.24%
# Iteration 9968/10000, Loss: 0.1642, Accuracy: 96.24%
# Iteration 9969/10000, Loss: 0.1642, Accuracy: 96.24%
# Iteration 9970/10000, Loss: 0.1642, Accuracy: 96.24%
# Iteration 9971/10000, Loss: 0.1642, Accuracy: 96.24%
# Iteration 9972/10000, Loss: 0.1642, Accuracy: 96.24%
# Iteration 9973/10000, Loss: 0.1642, Accuracy: 96.24%
# Iteration 9974/10000, Loss: 0.1642, Accuracy: 96.24%
# Iteration 9975/10000, Loss: 0.1642, Accuracy: 96.24%
# Iteration 9976/10000, Loss: 0.1642, Accuracy: 96.24%
# Iteration 9977/10000, Loss: 0.1642, Accuracy: 96.24%
# Iteration 9978/10000, Loss: 0.1642, Accuracy: 96.24%
# Iteration 9979/10000, Loss: 0.1642, Accuracy: 96.24%
# Iteration 9980/10000, Loss: 0.1641, Accuracy: 96.24%
# Iteration 9981/10000, Loss: 0.1641, Accuracy: 96.24%
# Iteration 9982/10000, Loss: 0.1641, Accuracy: 96.24%
# Iteration 9983/10000, Loss: 0.1641, Accuracy: 96.24%
# Iteration 9984/10000, Loss: 0.1641, Accuracy: 96.24%
# Iteration 9985/10000, Loss: 0.1641, Accuracy: 96.24%
# Iteration 9986/10000, Loss: 0.1641, Accuracy: 96.24%
# Iteration 9987/10000, Loss: 0.1641, Accuracy: 96.24%
# Iteration 9988/10000, Loss: 0.1641, Accuracy: 96.24%
# Iteration 9989/10000, Loss: 0.1641, Accuracy: 96.24%
# Iteration 9990/10000, Loss: 0.1641, Accuracy: 96.24%
# Iteration 9991/10000, Loss: 0.1641, Accuracy: 96.24%
# Iteration 9992/10000, Loss: 0.1641, Accuracy: 96.24%
# Iteration 9993/10000, Loss: 0.1641, Accuracy: 96.24%
# Iteration 9994/10000, Loss: 0.1641, Accuracy: 96.24%
# Iteration 9995/10000, Loss: 0.1641, Accuracy: 96.24%
# Iteration 9996/10000, Loss: 0.1640, Accuracy: 96.24%
# Iteration 9997/10000, Loss: 0.1640, Accuracy: 96.24%
# Iteration 9998/10000, Loss: 0.1640, Accuracy: 96.24%
# Iteration 9999/10000, Loss: 0.1640, Accuracy: 96.24%
# Iteration 10000/10000, Loss: 0.1640, Accuracy: 96.24%

# %%
# Visualize decision boundary after training
plt.scatter(features_train[:, 0], features_train[:, 1], s=5*np.ones(labels_train.size), c=labels_train, cmap='coolwarm')
xx, yy = np.meshgrid(np.linspace(0., 1., 300),
                     np.linspace(0., 1., 300))
zz = w[0, 0] * xx + w[0, 1] * yy + b - 0.5
plt.contourf(xx, yy, zz, levels=[-np.inf, 0, np.inf], colors=['blue', 'red'], alpha=0.25)
plt.title('Decision Boundary after Training')

# %% [markdown]
# ## 5. Evaluate Model with a New Dataset
# Let's generate a similar dataset using [make_blobs](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_blobs.html#sklearn.datasets.make_blobs) as used in the beginning of this practice.
# Make predictions and evaluate model with this newly generated dataset.

# %%
# Accuracy on training data
X_raw, y_raw = make_blobs(n_samples=512, centers=np.array([[5, 5], [7, 8]]), cluster_std=1.0,)
features_test = X_raw / X_raw.max(axis=0)  # Scale features to [-1, 1]
labels_test = y_raw.reshape(-1, 1)  # Reshape labels to be a column vector

# Visualize test data
plt.scatter(
    features_test[:, 0], 
    features_test[:, 1], 
    s=5*np.ones(labels_test.size), 
    c=labels_test, 
    cmap='managua'  # color map
)
# Visualize decision boundary on test data
plt.contourf(xx, yy, zz, levels=[-np.inf, 0, np.inf], colors=['orange', 'cyan'], alpha=0.25)
plt.title('Decision Boundary on Test Data')
# Out:
# Text(0.5, 1.0, 'Decision Boundary on Test Data')

# %% [markdown]
# Besides accuracy, a handful of metrics are useful to evaluate how sensitive/precise/balance the model is.
# A confusion matrix is a handy tool to visualize these metrics.

# %%
# Confusion Matrix for Test Data
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

preds_test = forward(features_test, w, b)
cm_test = confusion_matrix(labels_test, (preds_test >= 0.5).astype(int))
disp_test = ConfusionMatrixDisplay(confusion_matrix=cm_test, display_labels=[0, 1])
disp_test.plot(cmap='PuRd')
plt.title('Confusion Matrix - Test Data')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix - Test Data')

# %% [markdown]
# ### <font color=#582C83>(25%) Exercise 6: Classification Metrics</font>
# According to your confusion matrix on the **test dataset**. Please calculate the following metrics and write your answers below.
# > Let $0$ be negative, and $1$ be positive.
#
# - `Accuracy`=0.9551 (95.51%)
# - `Recall`=0.9570 (95.70%)
# - `Precision`=0.9533 (95.33%)
# - `F1 Score`=0.9552 (95.52%)
#
# <font color=#582C83>Assume the model is used by the quality control department in a factory to detect defective products (class 1).
# Please briefly state (2 sentences maximum) why or why not this model is good for this job.</font>
# > Please write down your answer below.
#
# This model is good for models that are low-critical such as toys or cheap parts, since the precision rate is very high and recall rate can detect more than 95% of defective models.  However, it's not so great for high-risk products such as auto parts or medical instruments since these items cannot have a less than certain detection rate due to their applications that are a statistic in mortality rates.

# %% [markdown]
# # Congratulations! You have finished this assignment!
